# %%
from collections import defaultdict
import math

# %%
# Step 1: 
def read_data(file_path):
    sentences = []
    with open(file_path, 'r', encoding='utf-8') as file:
        sentence = []
        for line in file:
            line = line.strip()
            if line and not line.startswith("#"):
                columns = line.split('\t')
                if len(columns) >= 2:
                    word, pos = columns[1], columns[3]
                    sentence.append((word, pos))
            elif sentence:
                sentences.append(sentence)
                sentence = []
    return sentences

# %%
train_data = read_data('C:/Users/rim-1/Downloads/train.conllu')
train_data
# Out:
# [[('Les', 'DET'),
#   ('commotions', 'NFP'),
#   ('cérébrales', 'ADJFP'),
#   ('sont', 'AUX'),
#   ('devenu', 'VPPMS'),
#   ('si', 'ADV'),
#   ('courantes', 'ADJFP'),
#   ('dans', 'PREP'),
#   ('ce', 'PDEMMS'),
#   ('sport', 'NMS'),
#   ("qu'", 'COSUB'),
#   ('on', 'PINDMS'),
#   ('les', 'PPOBJMS'),
#   ('considére', 'VERB'),
#   ('presque', 'ADV'),
#   ('comme', 'PREP'),
#   ('la', 'DETFS'),
#   ('routine', 'NFS'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('œuvre', 'NFS'),
#   ('est', 'AUX'),
#   ('située', 'VPPFS'),
#   ('dans', 'PREP'),
#   ('la', 'DETFS'),
#   ('galerie', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('batailles', 'NFP'),
#   (',', 'PUNCT'),
#   ('dans', 'PREP'),
#   ('le', 'DETMS'),
#   ('château', 'NMS'),
#   ('de', 'PREP'),
#   ('Versailles', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('comportement', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Turquie', 'PROPN'),
#   ('vis-à-vis', 'ADV'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('problème', 'NMS'),
#   ('palestinien', 'ADJMS'),
#   ('a', 'AUX'),
#   ('fait', 'VPPMS'),
#   ("qu'", 'COSUB'),
#   ('elle', 'PPER3FS'),
#   ("n'", 'ADV'),
#   ('est', 'VERB'),
#   ('plus', 'ADV'),
#   ('en', 'PREP'),
#   ('odeur', 'NFS'),
#   ('de', 'PREP'),
#   ('sainteté', 'NFS'),
#   ('auprès', 'ADV'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('communauté', 'NFS'),
#   ('juive', 'ADJFS'),
#   ('en', 'PREP'),
#   ('générale', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('américaine', 'ADJFS'),
#   ('en', 'PREP'),
#   ('particulier', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('Toutefois', 'ADV'),
#   (',', 'PUNCT'),
#   ('les', 'DET'),
#   ('filles', 'NFP'),
#   ('adorent', 'VERB'),
#   ('les', 'DET'),
#   ('desserts', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Ismene', 'PROPN'),
#   ('entre', 'VERB'),
#   ('et', 'COCO'),
#   ('annonce', 'VERB'),
#   ('que', 'COSUB'),
#   ("c'", 'PDEMMS'),
#   ('est', 'AUX'),
#   ('Farnace', 'PROPN'),
#   ('qui', 'PREL'),
#   ('a', 'AUX'),
#   ('mis', 'VERB'),
#   ('le', 'DETMS'),
#   ('feu', 'NMS'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('flotte', 'NFS'),
#   ('romaine', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('je', 'PPER1S'),
#   ('reviendrais', 'VERB'),
#   ('avec', 'PREP'),
#   ('plaisir', 'NMS'),
#   ('!', 'PUNCT')],
#  [('Les', 'DET'),
#   ('forfaits', 'NMP'),
#   ('comprennent', 'VERB'),
#   ('le', 'DETMS'),
#   ('transport', 'NMS'),
#   ('en', 'PREP'),
#   ('car', 'NMS'),
#   ('Grand', 'ADJMS'),
#   ('Tourisme', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('différents', 'ADJMP'),
#   ('lieux', 'NMP'),
#   ('de', 'PREP'),
#   ('départs', 'NMP'),
#   ('proposés', 'VPPMP'),
#   ('autour', 'ADV'),
#   ('de', 'PREP'),
#   ('Lyon', 'PROPN'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('forfait', 'NMS'),
#   ('de', 'PREP'),
#   ('ski', 'NMS'),
#   ('sur', 'PREP'),
#   ('le', 'DETMS'),
#   ('domaine', 'NMS'),
#   ('cité', 'VPPMS'),
#   (',', 'PUNCT'),
#   ('un', 'DINTMS'),
#   ('en-cas', 'NMS'),
#   ('petit-déjeuner', 'NMS'),
#   ('servi', 'VPPMS'),
#   ('à', 'PREP'),
#   ('votre', 'DET'),
#   ('arrivée', 'NFS'),
#   ('en', 'PREP'),
#   ('station', 'NFS'),
#   ('et', 'COCO'),
#   ('le', 'DETMS'),
#   ('service', 'NMS'),
#   ("d'", 'PREP'),
#   ('un', 'DINTMS'),
#   ('accompagnateur', 'NMS'),
#   ('salarié', 'ADJMS'),
#   ('assurant', 'VERB'),
#   ('la', 'DETFS'),
#   ('logistique', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('départs', 'NMP'),
#   ('et', 'COCO'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('retours', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('prévient', 'VERB'),
#   ('que', 'COSUB'),
#   ('de', 'DET'),
#   ('telles', 'ADJFP'),
#   ('agressions', 'NFP'),
#   ('sont', 'AUX'),
#   ('"', 'PUNCT'),
#   ('susceptibles', 'ADJFP'),
#   ("d'", 'PREP'),
#   ('entraîner', 'VERB'),
#   ('des', 'DET'),
#   ('poursuites', 'NFP'),
#   ('judiciaires', 'ADJFP'),
#   ('"', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Ils', 'PPER3MP'),
#   ('tiraient', 'VERB'),
#   ('à', 'PREP'),
#   ('balles', 'NFP'),
#   ('réelles', 'ADJFP'),
#   ('sur', 'PREP'),
#   ('la', 'DETFS'),
#   ('foule', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('château', 'NMS'),
#   ('est', 'AUX'),
#   ('ensuite', 'ADV'),
#   ('vendu', 'VPPMS'),
#   ('plusieurs', 'DET'),
#   ('fois', 'NFP'),
#   (';', 'PUNCT')],
#  [('En', 'PREP'),
#   ('effet', 'NMS'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('biréfringence', 'NFS'),
#   ("n'", 'ADV'),
#   ('étant', 'AUX'),
#   ('pas', 'ADV'),
#   ('visible', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('elle', 'PPER3FS'),
#   ("n'", 'ADV'),
#   ('est', 'AUX'),
#   ('pas', 'ADV'),
#   ('prépondérante', 'ADJFS'),
#   ('sur', 'PREP'),
#   ('le', 'DETMS'),
#   ('pouvoir', 'NMS'),
#   ('rotatoire', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('point', 'NMS'),
#   ('final', 'ADJMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('plate-forme', 'NFS'),
#   ('de', 'PREP'),
#   ('distribution', 'NFS'),
#   ('serait', 'AUX'),
#   ('basé', 'VPPMS'),
#   ('en', 'PREP'),
#   ('Autriche', 'PROPN'),
#   ('à', 'PREP'),
#   ('Baumgarten', 'PROPN'),
#   ('pour', 'PREP'),
#   ('rejoindre', 'VERB'),
#   ('ensuite', 'ADV'),
#   ('le', 'DETMS'),
#   ('réseau', 'NMS'),
#   ("d'", 'PREP'),
#   ('Europe', 'PROPN'),
#   ('centrale', 'ADJFS'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('ouest', 'NMS'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('information', 'NFS'),
#   ('génétique', 'ADJFS'),
#   ('est', 'AUX'),
#   ('codée', 'VPPFS'),
#   ('sous', 'PREP'),
#   ('forme', 'NFS'),
#   ("d'", 'PREP'),
#   ('ADN', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Motivé', 'VPPMS'),
#   ('par', 'PREP'),
#   ('la', 'DETFS'),
#   ('charité', 'NFS'),
#   ('chrétienne', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('communauté', 'NFS'),
#   ('a', 'AUX'),
#   ('changé', 'VPPMS'),
#   ('un', 'DINTMS'),
#   ('vieil', 'ADJMS'),
#   ('immeuble', 'NMS'),
#   ('abanbonné', 'VPPMS'),
#   ('où', 'ADV'),
#   ('se', 'PREF'),
#   ('pratiquaient', 'VERB'),
#   ("d'", 'PREP'),
#   ('ailleurs', 'ADV'),
#   ('de', 'DET'),
#   ('nombreux', 'ADJMP'),
#   ('échanges', 'NMP'),
#   ('de', 'PREP'),
#   ('drogues', 'NFP'),
#   ('en', 'PREP'),
#   ('ce', 'PDEMMS'),
#   ('logement', 'NMS'),
#   ('sûr', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('propre', 'ADJMS'),
#   ('et', 'COCO'),
#   ('abordable', 'ADJMS'),
#   ("qu'", 'PREL'),
#   ('il', 'PPER3MS'),
#   ('est', 'AUX'),
#   ("aujourd'hui", 'ADV'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('exploitait', 'VERB'),
#   ('un', 'DINTMS'),
#   ('site', 'NMS'),
#   ('de', 'PREP'),
#   ('haute', 'ADJFS'),
#   ('valeur', 'NFS'),
#   ('militaire', 'ADJFS'),
#   ('et', 'COCO'),
#   ('commerciale', 'ADJFS'),
#   ('comprenant', 'VERB'),
#   ('un', 'DINTMS'),
#   ('surplomb', 'NMS'),
#   ('rocheux', 'ADJ'),
#   ('dominant', 'VERB'),
#   ('en', 'PREP'),
#   ('à-pic', 'NMS'),
#   ('la', 'DETFS'),
#   ('rivière', 'NFS'),
#   ('Oust', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Plus', 'ADV'),
#   ('tard', 'ADV'),
#   ('dans', 'PREP'),
#   ('la', 'DETFS'),
#   ('saison', 'NFS'),
#   (',', 'PUNCT'),
#   ('ils', 'PPER3MP'),
#   ('consomment', 'VERB'),
#   ('beaucoup', 'ADV'),
#   ('de', 'PREP'),
#   ('baies', 'NFP'),
#   ('et', 'COCO'),
#   ('autres', 'ADJMP'),
#   ('petits', 'ADJMP'),
#   ('fruits', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Ils', 'PPER3MP'),
#   ('deviennent', 'VERB'),
#   ('alors', 'ADV'),
#   ('les', 'DET'),
#   ('Paladins', 'PROPN'),
#   (',', 'PUNCT'),
#   ('chevaliers', 'NMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('bien', 'NMS'),
#   ('chargés', 'VPPMP'),
#   ('de', 'PREP'),
#   ('défendre', 'VERB'),
#   ('élèves', 'NMP'),
#   ('et', 'COCO'),
#   ('professeurs', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('chevalier', 'NMS'),
#   ('lui', 'PPOBJMS'),
#   ('propose', 'VERB'),
#   ('une', 'DINTFS'),
#   ('partie', 'NFS'),
#   ("d'", 'PREP'),
#   ('échecs', 'NMP'),
#   (',', 'PUNCT'),
#   ('espérant', 'VERB'),
#   ('retarder', 'VERB'),
#   ("l'", 'DET'),
#   ('échéance', 'NFS'),
#   ('fatidique', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('temps', 'NMS'),
#   ('de', 'PREP'),
#   ('trouver', 'VERB'),
#   ('une', 'DINTFS'),
#   ('solution', 'NFS'),
#   ('à', 'PREP'),
#   ('ses', 'DET'),
#   ('problèmes', 'NMP'),
#   ('métaphysiques', 'ADJMP'),
#   (':', 'PUNCT'),
#   ('Dieu', 'PROPN'),
#   ('existe', 'VERB'),
#   ('-il', 'PPER3MS'),
#   ('?', 'PUNCT')],
#  [('Créée', 'VPPFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('cours', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('troisième', 'ADJMS'),
#   ('trimestre', 'NMS'),
#   ('1915', 'CHIF'),
#   ('comme', 'PREP'),
#   ('escadrille', 'NFS'),
#   ('MF', 'PROPN'),
#   ('93', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('elle', 'PPER3FS'),
#   ('a', 'AUX'),
#   ('disparu', 'VPPMS'),
#   ('en', 'PREP'),
#   ('même', 'ADJMS'),
#   ('temps', 'NMS'),
#   ('que', 'COSUB'),
#   ('la', 'DETFS'),
#   ('30e', 'ADJFS'),
#   ('Escadre', 'NFS'),
#   ('de', 'PREP'),
#   ('Chasse', 'NFS'),
#   ('à', 'PREP'),
#   ('laquelle', 'PRELFS'),
#   ('elle', 'PPER3FS'),
#   ('était', 'AUX'),
#   ('intégrée', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('On', 'PINDMS'),
#   ('ne', 'ADV'),
#   ('peut', 'VERB'),
#   ('éviter', 'VERB'),
#   ('de', 'PREP'),
#   ('penser', 'VERB'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('actualité', 'NFS'),
#   ('caractérisée', 'VPPFS'),
#   ('par', 'PREP'),
#   ("l'", 'DET'),
#   ('enlèvement', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('otages', 'NMP'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Niger', 'PROPN'),
#   ('--', 'PUNCT'),
#   ('dont', 'PREL'),
#   ('cinq', 'CHIF'),
#   ('Français', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ('est', 'AUX'),
#   ('déjà', 'ADV'),
#   ('soumise', 'VPPFS'),
#   ('à', 'PREP'),
#   ('rude', 'ADJFS'),
#   ('épreuve', 'NFS'),
#   ('avant', 'PREP'),
#   ('même', 'ADV'),
#   ("l'", 'DET'),
#   ('avènement', 'NMS'),
#   ('de', 'PREP'),
#   ('Flann', 'PROPN'),
#   ('Sinna', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [('"', 'PUNCT'),
#   ('Malgré', 'PREP'),
#   ('les', 'DET'),
#   ('efforts', 'NMP'),
#   ('consentis', 'VPPMP'),
#   ('par', 'PREP'),
#   ('quelques', 'DET'),
#   ('pays', 'NMP'),
#   (',', 'PUNCT'),
#   ('environ', 'ADV'),
#   ('155', 'CHIF'),
#   ('millions', 'NMP'),
#   ('de', 'PREP'),
#   ('personnes', 'NFP'),
#   ('--', 'PUNCT'),
#   ('soit', 'ADV'),
#   ('39', 'CHIF'),
#   ('%', 'SYM'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('population', 'NFS'),
#   ('--', 'PUNCT'),
#   ("n'", 'ADV'),
#   ('ont', 'VERB'),
#   ('pas', 'ADV'),
#   ('encore', 'ADV'),
#   ('accès', 'NOUN'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('eau', 'NFS'),
#   ('potable', 'ADJFS'),
#   ('en', 'PREP'),
#   ('Afrique', 'PROPN'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('Ouest', 'PROPN'),
#   ('et', 'COCO'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Centre', 'PROPN'),
#   ('"', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('selon', 'PREP'),
#   ('le', 'DETMS'),
#   ('texte', 'NMS'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('direction', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('fibres', 'NFP'),
#   ('est', 'AUX'),
#   ('donc', 'ADV'),
#   ('la', 'DETFS'),
#   ('direction', 'NFS'),
#   ('de', 'PREP'),
#   ('plus', 'ADV'),
#   ('grande', 'ADJFS'),
#   ('diffusivité', 'NFS'),
#   (',', 'PUNCT'),
#   ('indiquée', 'VPPFS'),
#   ('par', 'PREP'),
#   ('le', 'DETMS'),
#   ('vecteur', 'NMS'),
#   ('propre', 'ADJMS'),
#   ('associé', 'VPPMS'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('plus', 'ADV'),
#   ('grande', 'ADJFS'),
#   ('valeur', 'NFS'),
#   ('propre', 'ADJFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('tenseur', 'NMS'),
#   ('de', 'PREP'),
#   ('diffusion', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('experts', 'NMP'),
#   ('sont', 'AUX'),
#   ('unanimes', 'ADJMP'),
#   ('pour', 'PREP'),
#   ('dater', 'VERB'),
#   ('ce', 'PDEMMS'),
#   ('manuscrit', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('VIe', 'ADJMS'),
#   ('siècle', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ("s'", 'PREF'),
#   ('étend', 'VERB'),
#   ('sur', 'PREP'),
#   ('105,3', 'CHIF'),
#   ('km²', 'NMP'),
#   ('et', 'COCO'),
#   ('comptait', 'VERB'),
#   ('5633', 'CHIF'),
#   ('habitants', 'NMP'),
#   ('en', 'PREP'),
#   ('2010', 'CHIF'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('affaire', 'NFS'),
#   ('se', 'PREF'),
#   ('complique', 'VERB'),
#   ('un', 'DINTMS'),
#   ('peu', 'ADV'),
#   ('avec', 'PREP'),
#   ('les', 'DET'),
#   ('jeux', 'NMP'),
#   ('Super', 'PROPN'),
#   ('Nintendo', 'XFAMIL'),
#   ('ou', 'COCO'),
#   ("d'", 'PREP'),
#   ('autres', 'ADJMP'),
#   ('systèmes', 'NMP'),
#   (',', 'PUNCT'),
#   ('qui', 'PREL'),
#   ('stockent', 'VERB'),
#   ('les', 'DET'),
#   ('valeurs', 'NFP'),
#   ('RVB', 'MOTINC'),
#   ('absolues', 'ADJFP'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('couleurs', 'NFP'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('cathédrale', 'NFS'),
#   (',', 'PUNCT'),
#   ("l'", 'DET'),
#   ('une', 'PINDFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('plus', 'ADV'),
#   ('vastes', 'ADJFP'),
#   ('églises', 'NFP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('monde', 'NMS'),
#   ('arménien', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('est', 'AUX'),
#   ('bâtie', 'VPPFS'),
#   ('sur', 'PREP'),
#   ('le', 'DETMS'),
#   ('modèle', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('cathédrale', 'NFS'),
#   ("d'", 'PREP'),
#   ('Etchmiadzin', 'PROPN'),
#   (':', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ("s'", 'PREF'),
#   ('agit', 'VERB'),
#   ("d'", 'PREP'),
#   ('une', 'DINTFS'),
#   ('croix', 'NFS'),
#   ('libre', 'ADJFS'),
#   ('dotée', 'VPPFS'),
#   ('de', 'PREP'),
#   ('quatre', 'CHIF'),
#   ('absides', 'NFP'),
#   ('.', 'YPFOR')],
#  [('ARF', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('Application', 'NFS'),
#   ('Roll-over', 'NMS'),
#   ('Facility', 'NFS'),
#   (')', 'PUNCT'),
#   ('est', 'AUX'),
#   ('un', 'DINTMS'),
#   ('logiciel', 'NMS'),
#   ('de', 'PREP'),
#   ('haute', 'ADJFS'),
#   ('disponibilité', 'NFS'),
#   (',', 'PUNCT'),
#   ('fonctionnant', 'VERB'),
#   ('sous', 'PREP'),
#   ('AIX', 'PROPN'),
#   ('sur', 'PREP'),
#   ('les', 'DET'),
#   ('machines', 'NFP'),
#   ('Bull', 'PROPN'),
#   ('Escala', 'XFAMIL'),
#   ('ou', 'COCO'),
#   ('Linux', 'PROPN'),
#   ('sur', 'PREP'),
#   ('les', 'DET'),
#   ('serveurs', 'NMP'),
#   ('Bull', 'PROPN'),
#   ('Novascale', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('Abbé', 'PROPN'),
#   ('Othon', 'PROPN'),
#   ('y', 'PPOBJMP'),
#   ('envoie', 'VERB'),
#   ('Albéric', 'PROPN'),
#   ('accompagné', 'VPPMS'),
#   ('de', 'PREP'),
#   ('quelques', 'DET'),
#   ('moines', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('femelles', 'NFP'),
#   ('peuvent', 'VERB'),
#   ('réaliser', 'VERB'),
#   ('une', 'NUM'),
#   ('à', 'PREP'),
#   ('deux', 'CHIF'),
#   ('portées', 'NFP'),
#   ('par', 'PREP'),
#   ('an', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('printemps', 'NMS'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('automne', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ("s'", 'PREF'),
#   ('agit', 'VERB'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('17e', 'ADJMS'),
#   ('but', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('saison', 'NFS'),
#   ('pour', 'PREP'),
#   ("l'", 'DET'),
#   ('attaquant', 'NMS'),
#   ('finlandais', 'ADJ'),
#   ('.', 'YPFOR')],
#  [('Condamné', 'VPPMS'),
#   ('à', 'PREP'),
#   ('dix', 'CHIF'),
#   ('ans', 'NMP'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('passe', 'VERB'),
#   ('le', 'DETMS'),
#   ('reste', 'NMS'),
#   ('de', 'PREP'),
#   ('sa', 'DET'),
#   ('vie', 'NFS'),
#   ('en', 'PREP'),
#   ('prison', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Stephen', 'PROPN'),
#   ('accuse', 'VERB'),
#   ('Adeang', 'PROPN'),
#   ('et', 'COCO'),
#   ('les', 'DET'),
#   ('autres', 'ADJMP'),
#   ('députés', 'NMP'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('opposition', 'NFS'),
#   ("d'", 'PREP'),
#   ('avoir', 'AUX'),
#   ('voté', 'VPPMS'),
#   ('la', 'DETFS'),
#   ('loi', 'NFS'),
#   ('«', 'PUNCT'),
#   ('après', 'PREP'),
#   ('le', 'DETMS'),
#   ('coucher', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('soleil', 'NMS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('samedi', 'NMS'),
#   ('de', 'PREP'),
#   ('Pâques', 'PROPN'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('«', 'PUNCT'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('lueur', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('bougies', 'NFP'),
#   ('»', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Des', 'DET'),
#   ('panneaux', 'NMP'),
#   ('solaires', 'ADJMP'),
#   ('servent', 'VERB'),
#   ('également', 'ADV'),
#   ('à', 'PREP'),
#   ('chauffer', 'VERB'),
#   ("l'", 'DET'),
#   ('eau', 'NFS'),
#   ('chaude', 'ADJFS'),
#   ('sanitaire', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('Au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('contraire', 'NMS'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('rifampicine', 'NFS'),
#   ('diminue', 'VERB'),
#   ('son', 'DET'),
#   ('taux', 'NMS'),
#   ('sérique', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('Ce', 'PDEMMS'),
#   ('mécanisme', 'NMS'),
#   ('peut', 'VERB'),
#   ('permettre', 'VERB'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('fraude', 'NFS'),
#   ('de', 'PREP'),
#   ('durer', 'VERB'),
#   ('plusieurs', 'DET'),
#   ('années', 'NFP'),
#   (';', 'PUNCT')],
#  [('Vous', 'PREFP'),
#   ('pensez', 'VERB'),
#   ('que', 'COSUB'),
#   ('les', 'DET'),
#   ('Mauriciens', 'PROPN'),
#   ('ne', 'ADV'),
#   ('parlent', 'VERB'),
#   ('pas', 'ADV'),
#   ('suffisamment', 'ADV'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('situation', 'NFS'),
#   ('linguistique', 'ADJFS'),
#   ('de', 'PREP'),
#   ('leur', 'DET'),
#   ('pays', 'NMS'),
#   ('?', 'PUNCT')],
#  [('Tout', 'DET'),
#   ('ceci', 'PDEMMS'),
#   ('nous', 'PREFP'),
#   ('conduit', 'VERB'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('désagréable', 'ADJMS'),
#   ('sentiment', 'NMS'),
#   ('que', 'COSUB'),
#   ("l'", 'DET'),
#   ('économie', 'NFS'),
#   ('mondiale', 'ADJFS'),
#   ('se', 'PREF'),
#   ('dirige', 'VERB'),
#   ('tout', 'ADV'),
#   ('droit', 'ADV'),
#   ('vers', 'PREP'),
#   ('la', 'DETFS'),
#   ('déflation', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('hameaux', 'NMP'),
#   ('de', 'PREP'),
#   ('Faÿ', 'PROPN'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('Barbizon', 'PROPN'),
#   ('lui', 'PPOBJMS'),
#   ('étaient', 'AUX'),
#   ('reliés', 'VPPMP'),
#   ('par', 'PREP'),
#   ('le', 'DETMS'),
#   ('"', 'PUNCT'),
#   ('chemin', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Messe', 'PROPN'),
#   ('"', 'PUNCT'),
#   ('toujours', 'ADV'),
#   ('existant', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('De', 'PREP'),
#   ('plus', 'ADV'),
#   ("l'", 'DET'),
#   ('appartenance', 'NFS'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('ordre', 'NMS'),
#   ('équestre', 'ADJMS'),
#   ('était', 'AUX'),
#   ('nécessaire', 'ADJFS'),
#   ('pour', 'PREP'),
#   ('accéder', 'VERB'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('postes', 'NMP'),
#   ("d'", 'PREP'),
#   ('officier', 'NMS'),
#   ('dans', 'PREP'),
#   ("l'", 'DET'),
#   ('armée', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('Faune', 'PROPN'),
#   ('canarien', 'ADJMS'),
#   ('vole', 'VERB'),
#   ('en', 'PREP'),
#   ('une', 'DINTFS'),
#   ('génération', 'NFS'),
#   ('entre', 'PREP'),
#   ('juin', 'NMS'),
#   ('et', 'COCO'),
#   ('septembre', 'NMS'),
#   ('suivant', 'PREP'),
#   ('la', 'DETFS'),
#   ('sous-espèce', 'NFS'),
#   ('et', 'COCO'),
#   ("l'", 'DET'),
#   ('altitude', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Étant', 'AUX'),
#   ('atteint', 'VPPMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('syndrome', 'NMS'),
#   ('de', 'PREP'),
#   ('Marfan', 'PROPN'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('est', 'AUX'),
#   ('très', 'ADV'),
#   ('grand', 'ADJMS'),
#   ('et', 'COCO'),
#   ('mince', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('faut', 'VERB'),
#   ('attendre', 'VERB'),
#   ('1527', 'CHIF'),
#   ('pour', 'PREP'),
#   ('que', 'COSUB'),
#   ('nous', 'PREFP'),
#   ('parvienne', 'VERB'),
#   ('le', 'DETMS'),
#   ('plus', 'ADV'),
#   ('ancien', 'ADJMS'),
#   ('texte', 'NMS'),
#   (',', 'PUNCT'),
#   ('écrit', 'VPPMS'),
#   ('par', 'PREP'),
#   ('Jan', 'PROPN'),
#   ('Ymbrechts', 'XFAMIL'),
#   ('--', 'PUNCT'),
#   ('sacristain', 'NMS'),
#   ("d'", 'PREP'),
#   ('Evere', 'PROPN'),
#   ('--', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('concernant', 'VERB'),
#   ("l'", 'DET'),
#   ('adjudication', 'NFS'),
#   ("d'", 'PREP'),
#   ('un', 'DINTMS'),
#   ('nouveau', 'ADJMS'),
#   ('chœur', 'NMS'),
#   ('à', 'PREP'),
#   ('cette', 'PDEMFS'),
#   ('église', 'NFS'),
#   ('.', 'YPFOR')],
#  [("D'", 'PREP'),
#   ('un', 'DINTMS'),
#   ('coup', 'NMS'),
#   ('de', 'PREP'),
#   ('pied', 'NMS'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('le', 'PPOBJMS'),
#   ('fait', 'AUX'),
#   ('tomber', 'VERB'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('main', 'NFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('prêtre', 'NMS'),
#   (',', 'PUNCT'),
#   ('par', 'PREP'),
#   ('terre', 'NFS'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('A887', 'NFS'),
#   ('et', 'COCO'),
#   ("l'", 'DET'),
#   ('A87', 'NFS'),
#   ('traversent', 'VERB'),
#   ('Glenmoriston', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('cours', 'NMS'),
#   ('de', 'PREP'),
#   ('dessin', 'NMS'),
#   ('est', 'AUX'),
#   ('il', 'PPER3MS'),
#   ('pour', 'PREP'),
#   ('les', 'DET'),
#   ('débutants', 'NMP'),
#   ('?', 'PUNCT')],
#  [('Bien', 'ADV'),
#   ('que', 'COSUB'),
#   ('cette', 'PDEMFS'),
#   ('entreprise', 'NFS'),
#   ('ait', 'AUX'),
#   ('été', 'AUX'),
#   ('considérée', 'VPPFS'),
#   ('comme', 'COSUB'),
#   ('sans', 'PREP'),
#   ('espoir', 'NMS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('syndicat', 'NMS'),
#   ('persévéra', 'VERB'),
#   (',', 'PUNCT'),
#   ('même', 'ADV'),
#   ("s'", 'COSUB'),
#   ('il', 'PPER3MS'),
#   ('ne', 'ADV'),
#   ('pouvait', 'VERB'),
#   ('payer', 'VERB'),
#   ('que', 'ADV'),
#   ('huit', 'CHIF'),
#   ('jours', 'NMP'),
#   ('de', 'PREP'),
#   ('recherches', 'NFP'),
#   ('.', 'YPFOR')],
#  [('Tous', 'ADJMP'),
#   ('les', 'DET'),
#   ('matchs', 'NMP'),
#   ('sont', 'AUX'),
#   ('désignés', 'VPPMP'),
#   ('par', 'PREP'),
#   ('tirage', 'NMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('sort', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Larry', 'PROPN'),
#   ('Harlow', 'XFAMIL'),
#   ('a', 'AUX'),
#   ('fait', 'AUX'),
#   ('découvrir', 'VERB'),
#   ('le', 'DETMS'),
#   ('trompettiste', 'NMS'),
#   ('cubain', 'ADJMS'),
#   ('Alfredo', 'PROPN'),
#   ('"', 'PUNCT'),
#   ('Chocolate', 'NMS'),
#   ('"', 'PUNCT'),
#   ('Armenteros', 'XFAMIL'),
#   ('et', 'COCO'),
#   ('le', 'DETMS'),
#   ('tromboniste', 'NMS'),
#   ('Mark', 'PROPN'),
#   ('Weinstein', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('qui', 'PREL'),
#   ('a', 'AUX'),
#   ('co-arrangé', 'VPPMS'),
#   ("l'", 'DET'),
#   ('album', 'NMS'),
#   ('avec', 'PREP'),
#   ('lui', 'PPOBJMS'),
#   ('.', 'YPFOR')],
#  [('Depuis', 'PREP'),
#   ('1986', 'CHIF'),
#   (',', 'PUNCT'),
#   ('les', 'DET'),
#   ('émissions', 'NFP'),
#   ('de', 'PREP'),
#   ('Radio', 'PROPN'),
#   ('Chine', 'XFAMIL'),
#   ('Internationale', 'ADJFS'),
#   ('sont', 'AUX'),
#   ('relayées', 'VPPFP'),
#   ('par', 'PREP'),
#   ('les', 'DET'),
#   ('émetteurs', 'NMP'),
#   ('français', 'ADJ'),
#   ("d'", 'PREP'),
#   ('Issoudun', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('en', 'PREP'),
#   ('métropole', 'NFS'),
#   (')', 'PUNCT'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('Montsinéry-Tonnegrande', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('en', 'PREP'),
#   ('Guyane', 'PROPN'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Englebert', 'PROPN'),
#   ('exprime', 'VERB'),
#   ('son', 'DET'),
#   ('hostilité', 'NFS'),
#   ('et', 'COCO'),
#   ('semble', 'VERB'),
#   ('soutenu', 'VPPMS'),
#   ('par', 'PREP'),
#   ('le', 'DETMS'),
#   ('Cardinal', 'PROPN'),
#   ('Mercier', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Commandité', 'VPPMS'),
#   ('par', 'PREP'),
#   ('son', 'DET'),
#   ('oncle', 'NMS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('directeur', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('journal', 'NMS'),
#   ('«', 'PUNCT'),
#   ('La', 'DETFS'),
#   ('Tribune', 'PROPN'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('la', 'DETFS'),
#   ('journaliste', 'NFS'),
#   ('Diana', 'PROPN'),
#   ('Palmer', 'XFAMIL'),
#   ('se', 'PREF'),
#   ('rend', 'VERB'),
#   ('sur', 'PREP'),
#   ("l'", 'DET'),
#   ('île', 'NFS'),
#   ('de', 'PREP'),
#   ('Benalla', 'PROPN'),
#   ('et', 'COCO'),
#   ('est', 'AUX'),
#   ('kidnappée', 'VPPFS'),
#   ('par', 'PREP'),
#   ('des', 'DET'),
#   ('pirates', 'NMP'),
#   ('...', 'PUNCT')],
#  [('Un', 'DINTMS'),
#   ('membre', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('gouvernement', 'NMS'),
#   ('peut', 'VERB'),
#   ('également', 'ADV'),
#   ('servir', 'VERB'),
#   ('de', 'PREP'),
#   ('porte-parole', 'NMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('exécutif', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Ironiquement', 'ADV'),
#   (',', 'PUNCT'),
#   ('Trois', 'CHIF'),
#   ('morceaux', 'NMP'),
#   ('en', 'PREP'),
#   ('forme', 'NFS'),
#   ('de', 'PREP'),
#   ('poire', 'NFS'),
#   ('comporte', 'VERB'),
#   ('sept', 'CHIF'),
#   ('mouvements', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Elles', 'PPER3FP'),
#   ('faisaient', 'VERB'),
#   ("l'", 'DET'),
#   ('objet', 'NMS'),
#   ("d'", 'PREP'),
#   ('un', 'DINTMS'),
#   ('ordre', 'NMS'),
#   ('de', 'PREP'),
#   ('recherche', 'NFS'),
#   ('et', 'COCO'),
#   ("d'", 'PREP'),
#   ('arrestation', 'NFS'),
#   ('pour', 'PREP'),
#   ('avoir', 'AUX'),
#   ('participé', 'VPPMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('camp', 'NMS'),
#   ('--', 'PUNCT'),
#   ('également', 'ADV'),
#   ('dénommé', 'VPPMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Dignité', 'PROPN'),
#   ('--', 'PUNCT'),
#   ('et', 'COCO'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('affrontements', 'NMP'),
#   ('postérieurs', 'ADJMP'),
#   ('qui', 'PREL'),
#   ('ont', 'AUX'),
#   ('eu', 'VPPMS'),
#   ('lieu', 'NMS'),
#   ('dans', 'PREP'),
#   ('les', 'DET'),
#   ('rues', 'NFP'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('ville', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Ce', 'PDEMMS'),
#   ('test', 'NMS'),
#   ('intéresserait', 'VERB'),
#   ('plutôt', 'ADV'),
#   ('les', 'DET'),
#   ('ingénieurs', 'NMP'),
#   ('qui', 'PREL'),
#   ('songent', 'VERB'),
#   ('à', 'PREP'),
#   ('intégrer', 'VERB'),
#   ('ce', 'PDEMMS'),
#   ('moteur', 'NMS'),
#   ('dans', 'PREP'),
#   ('leurs', 'DET'),
#   ('propres', 'ADJMP'),
#   ('développements', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Jabba', 'PROPN'),
#   ('mène', 'VERB'),
#   ('une', 'DINTFS'),
#   ('vie', 'NFS'),
#   ('de', 'PREP'),
#   ('plaisirs', 'NMP'),
#   ('dans', 'PREP'),
#   ('son', 'DET'),
#   ('palais', 'NMS'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('reçoit', 'VERB'),
#   ('les', 'DET'),
#   ('visites', 'NFP'),
#   ('de', 'PREP'),
#   ('célèbres', 'ADJMP'),
#   ('contrebandiers', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Toujours', 'ADV'),
#   ('en', 'PREP'),
#   ('Géométrie', 'NFS'),
#   ('euclidienne', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('on', 'PINDMS'),
#   ('montre', 'VERB'),
#   ('que', 'COSUB'),
#   ('dans', 'PREP'),
#   ('un', 'DINTMS'),
#   ('triangle', 'NMS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('centre', 'NMS'),
#   ('de', 'PREP'),
#   ('gravité', 'NFS'),
#   ('G', 'MOTINC'),
#   (',', 'PUNCT'),
#   ("l'", 'DET'),
#   ('orthocentre', 'NMS'),
#   ('H', 'SYM'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('centre', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('cercle', 'NMS'),
#   ('circonscrit', 'VPPMS'),
#   ('Ω', 'MOTINC'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('le', 'DETMS'),
#   ('centre', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('cercle', 'NMS'),
#   ("d'", 'PREP'),
#   ('Euler', 'PROPN'),
#   ('E', 'MOTINC'),
#   ('sont', 'AUX'),
#   ('tous', 'ADJMP'),
#   ('les', 'DET'),
#   ('quatre', 'CHIF'),
#   ('alignés', 'VPPMP'),
#   ('sur', 'PREP'),
#   ('une', 'DINTFS'),
#   ('droite', 'NFS'),
#   ('dite', 'VPPFS'),
#   ('droite', 'NFS'),
#   ("d'", 'PREP'),
#   ('Euler', 'PROPN'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('triangle', 'NMS'),
#   (',', 'PUNCT'),
#   ('de', 'PREP'),
#   ('plus', 'ADV'),
#   ('ils', 'PPER3MP'),
#   ('sont', 'AUX'),
#   ('en', 'PREP'),
#   ('division', 'NFS'),
#   ('harmonique', 'ADJFS'),
#   ('(', 'PUNCT'),
#   ('dans', 'PREP'),
#   ('cet', 'PDEMMS'),
#   ('ordre', 'NMS'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('27', 'CHIF'),
#   ('mai', 'NMS'),
#   ('2011', 'CHIF'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('Président', 'NMS'),
#   ('chargé', 'VPPMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('instruction', 'NFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Tribunal', 'PROPN'),
#   ('de', 'PREP'),
#   ('grande', 'ADJFS'),
#   ('instance', 'NFS'),
#   ('de', 'PREP'),
#   ('Paris', 'PROPN'),
#   ('rend', 'VERB'),
#   ('une', 'DINTFS'),
#   ('ordonnance', 'NFS'),
#   ('de', 'PREP'),
#   ('non-lieu', 'NMS'),
#   ('pour', 'PREP'),
#   ('charges', 'NFP'),
#   ('insuffisantes', 'ADJFP'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('encontre', 'NFS'),
#   ("d'", 'PREP'),
#   ('Yves', 'PROPN'),
#   ('Poey', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [('Ses', 'DET'),
#   ('habitants', 'NMP'),
#   ('sont', 'AUX'),
#   ('appelés', 'VPPMP'),
#   ('les', 'DET'),
#   ('Paydrets', 'PROPN'),
#   ('et', 'COCO'),
#   ('les', 'DET'),
#   ('Paydrètes', 'PROPN'),
#   (';', 'PUNCT')],
#  [('Bien', 'ADV'),
#   ('évidemment', 'ADV'),
#   ('tous', 'ADJMP'),
#   ('les', 'DET'),
#   ('matériaux', 'NMP'),
#   ('de', 'PREP'),
#   ('valeur', 'NFS'),
#   ('avaient', 'AUX'),
#   ('été', 'AUX'),
#   ('prélevés', 'VPPMP'),
#   ('depuis', 'PREP'),
#   ('longtemps', 'ADV'),
#   (',', 'PUNCT'),
#   ('cependant', 'ADV'),
#   ('un', 'DINTMS'),
#   ('certain', 'ADJMS'),
#   ('nombre', 'NMS'),
#   ("d'", 'PREP'),
#   ('artefacts', 'NMP'),
#   ('caractéristiques', 'ADJMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('viatique', 'NMS'),
#   ('funéraire', 'ADJMS'),
#   ('royal', 'ADJMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('XVIIIe', 'ADJFS'),
#   ('dynastie', 'NFS'),
#   ('ont', 'AUX'),
#   ('pu', 'VPPMS'),
#   ('être', 'AUX'),
#   ('retrouvés', 'VPPMP'),
#   ('et', 'COCO'),
#   ('dont', 'PREL'),
#   ('le', 'DETMS'),
#   ('tombeau', 'NMS'),
#   ('de', 'PREP'),
#   ('Toutânkhamon', 'PROPN'),
#   ('livrera', 'VERB'),
#   ('plus', 'ADV'),
#   ('tard', 'ADV'),
#   ('un', 'DINTMS'),
#   ('ensemble', 'NMS'),
#   ('quasi', 'ADV'),
#   ('complet', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('a', 'AUX'),
#   ('sauté', 'VPPMS'),
#   ('sur', 'PREP'),
#   ('Mourinho', 'PROPN'),
#   (',', 'PUNCT'),
#   ('en', 'PREP'),
#   ('demandant', 'VERB'),
#   ('à', 'PREP'),
#   ('haute', 'ADJFS'),
#   ('voix', 'NFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Portugais', 'PROPN'),
#   ('de', 'PREP'),
#   ('respecter', 'VERB'),
#   ('les', 'DET'),
#   ('règles', 'NFP'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('rester', 'VERB'),
#   ('dans', 'PREP'),
#   ('la', 'DETFS'),
#   ('zone', 'NFS'),
#   ('de', 'PREP'),
#   ('direction', 'NFS'),
#   ('pour', 'PREP'),
#   ('entraîneurs', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ('reste', 'VERB'),
#   ('actuellement', 'ADV'),
#   ('dans', 'PREP'),
#   ("l'", 'DET'),
#   ('attente', 'NFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('verdict', 'NMS'),
#   ('final', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('Des', 'DET'),
#   ('innocents', 'NMP'),
#   ('se', 'PREF'),
#   ('trouvent', 'VERB'),
#   ('impliqués', 'VPPMP'),
#   ('dans', 'PREP'),
#   ('des', 'DET'),
#   ('affaires', 'NFP'),
#   ('comme', 'PREP'),
#   ('celle-ci', 'PDEMFS'),
#   ('alors', 'ADV'),
#   ("qu'", 'COSUB'),
#   ('ils', 'PPER3MP'),
#   ('sont', 'AUX'),
#   ('en', 'PREP'),
#   ('fait', 'NMS'),
#   ('utilisés', 'VPPMP'),
#   ('dans', 'PREP'),
#   ('des', 'DET'),
#   ('stratagèmes', 'NMP'),
#   ('politiques', 'ADJMP'),
#   ('.', 'YPFOR'),
#   ('"', 'PUNCT')],
#  [('Les', 'DET'),
#   ('soldats', 'NMP'),
#   ('pillent', 'VERB'),
#   ('les', 'DET'),
#   ('maisons', 'NFP'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('secrétaire', 'NMS'),
#   ('général', 'ADJMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('nations', 'NFP'),
#   ('Unies', 'ADJFP'),
#   (',', 'PUNCT'),
#   ('Ban', 'PROPN'),
#   ('ki-Moon', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('a', 'AUX'),
#   ('soulevé', 'VPPMS'),
#   ("d'", 'PREP'),
#   ('une', 'DINTFS'),
#   ('manière', 'NFS'),
#   ('claire', 'ADJFS'),
#   ('et', 'COCO'),
#   ('objective', 'ADJFS'),
#   (',', 'PUNCT'),
#   ('dans', 'PREP'),
#   ('son', 'DET'),
#   ('rapport', 'NMS'),
#   ('publié', 'VPPMS'),
#   ('vendredi', 'NMS'),
#   ('et', 'COCO'),
#   ('qui', 'PREL'),
#   ('sera', 'AUX'),
#   ('examiné', 'VPPMS'),
#   ('mardi', 'NMS'),
#   ('prochain', 'ADJMS'),
#   ('par', 'PREP'),
#   ('le', 'DETMS'),
#   ('Conseil', 'NMS'),
#   ('de', 'PREP'),
#   ('sécurité', 'NFS'),
#   (',', 'PUNCT'),
#   ("l'", 'DET'),
#   ('urgence', 'NFS'),
#   ('de', 'PREP'),
#   ('faire', 'VERB'),
#   ('face', 'NFS'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('situation', 'NFS'),
#   ('relative', 'ADJFS'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('violations', 'NFP'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('droits', 'NMP'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('Homme', 'NMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Sahara', 'PROPN'),
#   ('occidental', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('En', 'PREP'),
#   ('géométrie', 'NFS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('dodécadodécaèdre', 'NMS'),
#   ('tronqué', 'VPPMS'),
#   ('est', 'AUX'),
#   ('un', 'DINTMS'),
#   ('polyèdre', 'NMS'),
#   ('uniforme', 'ADJMS'),
#   ('non-convexe', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('indexé', 'VPPMS'),
#   ('sous', 'PREP'),
#   ('le', 'DETMS'),
#   ('nom', 'NMS'),
#   ('U59', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Tout', 'ADV'),
#   ('en', 'PREP'),
#   ('regrettant', 'VERB'),
#   ('que', 'COSUB'),
#   ('le', 'DETMS'),
#   ('Conseil', 'NMS'),
#   ('de', 'PREP'),
#   ('sécurité', 'NFS'),
#   ('"', 'PUNCT'),
#   ("n'", 'ADV'),
#   ('assume', 'VERB'),
#   ('toujours', 'ADV'),
#   ('pas', 'ADV'),
#   ('ses', 'DET'),
#   ('responsabilités', 'NFP'),
#   ('face', 'NOUN'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('tragédie', 'NFS'),
#   ('syrienne', 'ADJFS'),
#   ('"', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('avec', 'PREP'),
#   ('notamment', 'ADV'),
#   ('le', 'DETMS'),
#   ('refus', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Russie', 'PROPN'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Chine', 'PROPN'),
#   ('de', 'PREP'),
#   ('voter', 'VERB'),
#   ('des', 'DET'),
#   ('sanctions', 'NFP'),
#   ('contre', 'PREP'),
#   ('Damas', 'PROPN'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('a', 'AUX'),
#   ('exclu', 'VPPMS'),
#   ('toute', 'DET'),
#   ('initiative', 'NFS'),
#   ('française', 'ADJFS'),
#   ('en', 'PREP'),
#   ('dehors', 'NOUN'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('cadre', 'NMS'),
#   ('légal', 'ADJMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('Nations', 'NFP'),
#   ('unies', 'ADJFP'),
#   ('.', 'YPFOR')],
#  [("C'", 'PDEMMS'),
#   ('est', 'AUX'),
#   ("l'", 'DET'),
#   ('une', 'PINDFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('trois', 'CHIF'),
#   ('banlieues', 'NFP'),
#   ('où', 'ADV'),
#   ('ce', 'PDEMMS'),
#   ('trafic', 'NMS'),
#   ('domine', 'VERB'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ("s'", 'PREF'),
#   ('est', 'AUX'),
#   ('donné', 'VPPMS'),
#   ("jusqu'", 'PREP'),
#   ('à', 'PREP'),
#   ('mi-août', 'NFS'),
#   ('pour', 'PREP'),
#   ('y', 'PPOBJFS'),
#   ('réfléchir', 'VERB'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('crée', 'VERB'),
#   ('alors', 'ADV'),
#   ('la', 'DETFS'),
#   ('vis', 'NFS'),
#   ('aérienne', 'ADJFS'),
#   ('(', 'PUNCT'),
#   ('ou', 'COCO'),
#   ('hélice', 'NFS'),
#   ('ou', 'COCO'),
#   ('aile', 'NFS'),
#   ('tournante', 'ADJFS'),
#   ('hélicoïde', 'ADJFS'),
#   ('...', 'PUNCT'),
#   (')', 'PUNCT'),
#   ('avec', 'PREP'),
#   ('une', 'DINTFS'),
#   ('simple', 'ADJFS'),
#   ('vis', 'NFS'),
#   ('passée', 'VPPFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('milieu', 'NMS'),
#   ('de', 'PREP'),
#   ('deux', 'CHIF'),
#   ('plaques', 'NFP'),
#   ('de', 'PREP'),
#   ('bois', 'NOUN'),
#   ('en', 'PREP'),
#   ("s'", 'PREF'),
#   ('inspirant', 'VERB'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('principe', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Vis', 'NFS'),
#   ("d'", 'PREP'),
#   ('Archimède', 'PROPN'),
#   (',', 'PUNCT'),
#   ('utilisée', 'VPPFS'),
#   ('dès', 'PREP'),
#   ("l'", 'DET'),
#   ('antiquité', 'NFS'),
#   ('pour', 'PREP'),
#   ('monter', 'VERB'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('eau', 'NFS'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('premiers', 'ADJMP'),
#   ('AVN', 'PROPN'),
#   ('Awards', 'XFAMIL'),
#   ('sont', 'AUX'),
#   ('décernés', 'VPPMP'),
#   ('en', 'PREP'),
#   ('février', 'NMS'),
#   ('1984', 'CHIF'),
#   (',', 'PUNCT'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('titre', 'NMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('année', 'NFS'),
#   ('1983', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('À', 'PREP'),
#   ('partir', 'VERB'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('XXIe', 'ADJMS'),
#   ('siècle', 'NMS'),
#   (',', 'PUNCT'),
#   ('les', 'DET'),
#   ('recensements', 'NMP'),
#   ('réels', 'ADJMP'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('communes', 'NFP'),
#   ('de', 'PREP'),
#   ('moins', 'ADV'),
#   ('de', 'PREP'),
#   ('10 000', 'CHIF'),
#   ('habitants', 'NMP'),
#   ('ont', 'VERB'),
#   ('lieu', 'NMS'),
#   ('tous', 'ADJMP'),
#   ('les', 'DET'),
#   ('cinq', 'CHIF'),
#   ('ans', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('en', 'PPOBJMS'),
#   ('fut', 'VERB'),
#   ('comme', 'COSUB'),
#   ('de', 'PREP'),
#   ('tout', 'ADJMS'),
#   ('ce', 'PDEMMS'),
#   ("qu'", 'PREL'),
#   ('il', 'PPER3MS'),
#   ('avait', 'AUX'),
#   ('fait', 'VPPMS'),
#   ("jusqu'", 'PREP'),
#   ('alors', 'ADV'),
#   (':', 'PUNCT'),
#   ('les', 'DET'),
#   ('uns', 'PINDMP'),
#   ("s'", 'PREF'),
#   ('en', 'PPOBJMP'),
#   ('édifièrent', 'VERB'),
#   (',', 'PUNCT'),
#   ('les', 'DET'),
#   ('autres', 'PRON'),
#   ("s'", 'PREF'),
#   ('en', 'PPOBJMP'),
#   ('scandalisèrent', 'VERB'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('équipe', 'NFS'),
#   ('la', 'DETFS'),
#   ('mieux', 'ADV'),
#   ('classée', 'ADJFS'),
#   ('dispute', 'VERB'),
#   ('le', 'DETMS'),
#   ('premier', 'ADJMS'),
#   ('match', 'NMS'),
#   ('à', 'PREP'),
#   ('domicile', 'NMS'),
#   ('puis', 'ADV'),
#   ('se', 'PREF'),
#   ('déplace', 'VERB'),
#   ('chez', 'PREP'),
#   ('son', 'DET'),
#   ('adversaire', 'NMS'),
#   ('lors', 'ADV'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('seconde', 'ADJFS'),
#   ('rencontre', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Louise', 'PROPN'),
#   ('de', 'PREP'),
#   ('Bretagne', 'XFAMIL'),
#   ('a', 'AUX'),
#   ('alors', 'ADV'),
#   ('assuré', 'VPPMS'),
#   ("l'", 'DET'),
#   ('éducation', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('quatre', 'CHIF'),
#   ('enfants', 'NOUN'),
#   ('de', 'PREP'),
#   ('Gui', 'PROPN'),
#   ('II', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Cette', 'PDEMFS'),
#   ('tour', 'NFS'),
#   ('de', 'PREP'),
#   ('48', 'CHIF'),
#   ('m', 'NMP'),
#   ('a', 'AUX'),
#   ('été', 'AUX'),
#   ('achevée', 'VPPFS'),
#   ('en', 'PREP'),
#   ('1962', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('On', 'PINDMS'),
#   ('en', 'PPOBJMS'),
#   ('retrouve', 'VERB'),
#   ('aussi', 'ADV'),
#   ('un', 'DINTMS'),
#   ('peu', 'ADV'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Canada', 'PROPN'),
#   ('et', 'COCO'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('États-Unis', 'PROPN'),
#   (',', 'PUNCT'),
#   ('comme', 'COSUB'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('Nouveau-Brunswick', 'PROPN'),
#   ('et', 'COCO'),
#   ('dans', 'PREP'),
#   ("l'", 'DET'),
#   ('Est', 'NMS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('Ontario', 'PROPN'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('dans', 'PREP'),
#   ('le', 'DETMS'),
#   ('Nord', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Nouvelle-Angleterre', 'PROPN'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('New-York', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('ne', 'ADV'),
#   ('se', 'PREF'),
#   ('représenta', 'VERB'),
#   ('pas', 'ADV'),
#   ('en', 'PREP'),
#   ('1972', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('coopératives', 'NFP'),
#   ('ne', 'ADV'),
#   ('sont', 'AUX'),
#   ('pas', 'ADV'),
#   ('de', 'PREP'),
#   ('gauche', 'NFS'),
#   ('ou', 'COCO'),
#   ('de', 'PREP'),
#   ('droite', 'NFS'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ("s'", 'PREF'),
#   ('agit', 'VERB'),
#   ('seulement', 'ADV'),
#   ('de', 'PREP'),
#   ('logements', 'NMP'),
#   ('gérés', 'VPPMP'),
#   ('par', 'PREP'),
#   ('les', 'DET'),
#   ('gens', 'NOUN'),
#   ('dont', 'PREL'),
#   ('le', 'DETMS'),
#   ('but', 'NMS'),
#   ("n'", 'ADV'),
#   ('est', 'VERB'),
#   ('pas', 'ADV'),
#   ('de', 'PREP'),
#   ('faire', 'VERB'),
#   ('du', 'DINTMS'),
#   ('profit', 'NMS'),
#   ('mais', 'COCO'),
#   ("d'", 'PREP'),
#   ('habiter', 'VERB'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('titre', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('jeu', 'NMS'),
#   ('est', 'AUX'),
#   ('une', 'DINTFS'),
#   ('référence', 'NFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('film', 'NMS'),
#   ('Clash', 'MOTINC'),
#   ('of', 'MOTINC'),
#   ('the', 'MOTINC'),
#   ('Titans', 'MOTINC'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('la', 'DETFS'),
#   ('majorité', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('noms', 'NMP'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('niveaux', 'NMP'),
#   ('comprennent', 'VERB'),
#   ('des', 'DET'),
#   ('références', 'NFP'),
#   ('cinématographiques', 'ADJFP'),
#   ('.', 'YPFOR')],
#  [('Cependant', 'ADV'),
#   (',', 'PUNCT'),
#   ("n'", 'ADV'),
#   ('y', 'PPOBJFP'),
#   ('a', 'VERB'),
#   ('-t', 'PART'),
#   ('-il', 'PPER3MS'),
#   ('pas', 'ADV'),
#   ('là', 'ADV'),
#   ('un', 'DINTMS'),
#   ('contresens', 'NMS'),
#   ('complet', 'ADJMS'),
#   ('?', 'PUNCT')],
#  [('Pour', 'PREP'),
#   ('ce', 'PRON'),
#   ('qui', 'PREL'),
#   ('est', 'AUX'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('printemps', 'NMS'),
#   ('arabe', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('nous', 'PREFP'),
#   ('avons', 'AUX'),
#   ('insisté', 'VPPMS'),
#   ('avec', 'PREP'),
#   ("l'", 'DET'),
#   ('UE', 'PROPN'),
#   ('pour', 'PREP'),
#   ('soutenir', 'VERB'),
#   ('dans', 'PREP'),
#   ('le', 'DETMS'),
#   ('cadre', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('nouvelle', 'ADJFS'),
#   ('politique', 'NFS'),
#   ('de', 'PREP'),
#   ('voisinage', 'NMS'),
#   ('européenne', 'ADJFS'),
#   ('la', 'DETFS'),
#   ('réalisation', 'NFS'),
#   ("d'", 'PREP'),
#   ('une', 'DINTFS'),
#   ('intégration', 'NFS'),
#   ('économique', 'ADJFS'),
#   ('avec', 'PREP'),
#   ('les', 'DET'),
#   ('pays', 'NMP'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('Afrique', 'PROPN'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('nord', 'NMS'),
#   ('"', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('deux', 'CHIF'),
#   ('barmans', 'NMP'),
#   ('salariés', 'ADJMP'),
#   (',', 'PUNCT'),
#   ('sans', 'PREP'),
#   ('aucun', 'DET'),
#   ('sourire', 'NMS'),
#   (',', 'PUNCT'),
#   ('passent', 'VERB'),
#   ('leur', 'DET'),
#   ('temps', 'NMS'),
#   ('à', 'PREP'),
#   ('rincer', 'VERB'),
#   ('la', 'DETFS'),
#   ('vaisselle', 'NFS'),
#   ('sans', 'PREP'),
#   ('mettre', 'VERB'),
#   ('une', 'DINTFS'),
#   ('quelconque', 'ADJFS'),
#   ('ambiance', 'NFS'),
#   ('dans', 'PREP'),
#   ('ce', 'PDEMMS'),
#   ('bar', 'NMS'),
#   ('où', 'ADV'),
#   ('la', 'DETFS'),
#   ('musique', 'NFS'),
#   ('domine', 'VERB'),
#   ('avec', 'PREP'),
#   ('force', 'NFS'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('propreté', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('toilettes', 'NFP'),
#   ('est', 'AUX'),
#   ('toujours', 'ADV'),
#   ('impeccable', 'ADJFS'),
#   ('.', 'YPFOR')],
#  [('Selon', 'PREP'),
#   ('la', 'DETFS'),
#   ('tradition', 'NFS'),
#   ('religieuse', 'ADJFS'),
#   ('chinoise', 'ADJFS'),
#   ('où', 'ADV'),
#   ('la', 'DETFS'),
#   ('généalogie', 'NFS'),
#   ('prime', 'VERB'),
#   ('sur', 'PREP'),
#   ("l'", 'DET'),
#   ('idéologie', 'NFS'),
#   ('pour', 'PREP'),
#   ('la', 'DETFS'),
#   ('détermination', 'NFS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('dénomination', 'NFS'),
#   (',', 'PUNCT'),
#   ('tout', 'DET'),
#   ('abbé', 'NMS'),
#   ('qui', 'PREL'),
#   ('peut', 'VERB'),
#   ('faire', 'AUX'),
#   ('remonter', 'VERB'),
#   ('sa', 'DET'),
#   ('lignée', 'NFS'),
#   ('à', 'PREP'),
#   ('un', 'DINTMS'),
#   ('maître', 'NMS'),
#   ('Chan', 'PROPN'),
#   (',', 'PUNCT'),
#   ('quelle', 'ADJFS'),
#   ('que', 'COSUB'),
#   ('soit', 'AUX'),
#   ('la', 'DETFS'),
#   ('nature', 'NFS'),
#   ('de', 'PREP'),
#   ('ses', 'DET'),
#   ('pratiques', 'NFP'),
#   (',', 'PUNCT'),
#   ('est', 'AUX'),
#   ('en', 'PREP'),
#   ('droit', 'NMS'),
#   ('de', 'PREP'),
#   ('se', 'PREF'),
#   ('réclamer', 'VERB'),
#   ('de', 'PREP'),
#   ('ce', 'PDEMMS'),
#   ('courant', 'NMS'),
#   (',', 'PUNCT'),
#   ('où', 'ADV'),
#   ('dominent', 'VERB'),
#   ('après', 'PREP'),
#   ('846', 'CHIF'),
#   ('deux', 'CHIF'),
#   ('branches', 'NFP'),
#   (':', 'PUNCT'),
#   ('Linji', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('临济', 'PROPN'),
#   (')', 'PUNCT'),
#   ('qui', 'PREL'),
#   ('remonte', 'VERB'),
#   ('à', 'PREP'),
#   ('Línjì', 'PROPN'),
#   ('Yìxuán', 'XFAMIL'),
#   ('临济', 'PROPN'),
#   ('义', 'XFAMIL'),
#   ('玄', 'XFAMIL'),
#   ('(', 'PUNCT'),
#   ('?', 'PUNCT'),
#   ('-', 'PUNCT'),
#   ('869', 'CHIF'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('recensement', 'NMS'),
#   ('de', 'PREP'),
#   ('1991', 'CHIF'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('comptait', 'VERB'),
#   ('55', 'CHIF'),
#   ('habitants', 'NMP'),
#   (',', 'PUNCT'),
#   ('tous', 'ADJMP'),
#   ('serbes', 'ADJMP'),
#   ('.', 'YPFOR')],
#  [('Certaines', 'DET'),
#   ('personnes', 'NFP'),
#   ('sont', 'AUX'),
#   ('battues', 'VPPFP'),
#   ('et', 'COCO'),
#   ('il', 'PPER3MS'),
#   ('y', 'PPOBJMS'),
#   ('a', 'VERB'),
#   ('de', 'DET'),
#   ('nombreuses', 'ADJFP'),
#   ('arrestations', 'NFP'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('Yougoslavie', 'PROPN'),
#   ("n'", 'ADV'),
#   ('a', 'AUX'),
#   ('pas', 'ADV'),
#   ('entretenu', 'VPPMS'),
#   ('de', 'DET'),
#   ('relations', 'NFP'),
#   ('diplomatiques', 'ADJFP'),
#   ('avec', 'PREP'),
#   ('des', 'DET'),
#   ('pays', 'NMP'),
#   ('comme', 'PREP'),
#   ('le', 'DETMS'),
#   ('Portugal', 'PROPN'),
#   ("jusqu'", 'PREP'),
#   ('en', 'PREP'),
#   ('1974', 'CHIF'),
#   (',', 'PUNCT'),
#   ("l'", 'DET'),
#   ('Espagne', 'PROPN'),
#   ("jusqu'", 'PREP'),
#   ('en', 'PREP'),
#   ('1975', 'CHIF'),
#   ('ou', 'COCO'),
#   ("l'", 'DET'),
#   ('Afrique', 'PROPN'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Sud', 'NMS'),
#   ('à', 'PREP'),
#   ('cause', 'NFS'),
#   ('de', 'PREP'),
#   ('son', 'DET'),
#   ('régime', 'NMS'),
#   ("d'", 'PREP'),
#   ('apartheid', 'NMS'),
#   ('.', 'YPFOR')],
#  [('APEX', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('acronyme', 'NMS'),
#   ('de', 'PREP'),
#   ('«', 'PUNCT'),
#   ('Additive', 'MOTINC'),
#   ('system', 'MOTINC'),
#   ('of', 'MOTINC'),
#   ('Photography', 'MOTINC'),
#   ('EXposure', 'MOTINC'),
#   ('»', 'PUNCT'),
#   (')', 'PUNCT'),
#   ('est', 'AUX'),
#   ('une', 'DINTFS'),
#   ('méthode', 'NFS'),
#   ('de', 'PREP'),
#   ('calcul', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('temps', 'NMS'),
#   ("d'", 'PREP'),
#   ('exposition', 'NFS'),
#   ('basée', 'VPPFS'),
#   ('sur', 'PREP'),
#   ('une', 'DINTFS'),
#   ('mesure', 'NFS'),
#   ('en', 'PREP'),
#   ('Ev', 'MOTINC'),
#   ('(', 'PUNCT'),
#   ('Exposure', 'MOTINC'),
#   ('value', 'MOTINC'),
#   (')', 'PUNCT'),
#   ('adoptée', 'VPPFS'),
#   ('par', 'PREP'),
#   ('la', 'DETFS'),
#   ('plupart', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('posemètres', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Bien', 'ADV'),
#   ("qu'", 'COSUB'),
#   ('ils', 'PPER3MP'),
#   ('cultivent', 'VERB'),
#   ("l'", 'DET'),
#   ('art', 'NMS'),
#   ('de', 'PREP'),
#   ('disparaître', 'VERB'),
#   ('derrière', 'PREP'),
#   ('les', 'DET'),
#   ('auteurs', 'NMP'),
#   ("qu'", 'PREL'),
#   ('ils', 'PPER3MP'),
#   ('défendent', 'VERB'),
#   (',', 'PUNCT'),
#   ('les', 'DET'),
#   ('éditeurs', 'PROPN'),
#   ('ont', 'VERB'),
#   ('une', 'DINTFS'),
#   ('histoire', 'NFS'),
#   ('parfois', 'ADV'),
#   ('aussi', 'ADV'),
#   ('palpitante', 'ADJFS'),
#   ('que', 'COSUB'),
#   ('celle', 'PDEMFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('personnages', 'NMP'),
#   ('de', 'PREP'),
#   ('roman', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Puis', 'ADV'),
#   ('elle', 'PPER3FS'),
#   ('se', 'PREF'),
#   ('repose', 'VERB'),
#   ('en', 'PREP'),
#   ('Calabre', 'PROPN'),
#   ('pendant', 'PREP'),
#   ('le', 'DETMS'),
#   ('reste', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('mois', 'NMS'),
#   ("d'", 'PREP'),
#   ('août', 'NMS'),
#   ('et', 'COCO'),
#   ('en', 'PREP'),
#   ('début', 'NMS'),
#   ('de', 'PREP'),
#   ('septembre', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Criton', 'PROPN'),
#   ('sait', 'VERB'),
#   ('que', 'COSUB'),
#   ('Socrate', 'PROPN'),
#   ('est', 'AUX'),
#   ('aussi', 'ADV'),
#   ('fidèle', 'ADJ'),
#   ('que', 'COSUB'),
#   ('lui', 'PPOBJMS'),
#   ('et', 'COCO'),
#   ('il', 'PPER3MS'),
#   ('pense', 'VERB'),
#   ('que', 'COSUB'),
#   ('si', 'COSUB'),
#   ('Socrate', 'PROPN'),
#   ('ne', 'ADV'),
#   ('se', 'PREF'),
#   ('sauve', 'VERB'),
#   ('pas', 'ADV'),
#   ('pour', 'PREP'),
#   ('lui-même', 'PPOBJMS'),
#   (',', 'PUNCT'),
#   ('peut-être', 'ADV'),
#   ('se', 'PREF'),
#   ('sauvera', 'VERB'),
#   ('-t', 'PART'),
#   ('-il', 'PPER3MS'),
#   ('pour', 'PREP'),
#   ('ses', 'DET'),
#   ('amis', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Le', 'DETMS'),
#   ('tenant', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('titre', 'NMS'),
#   (',', 'PUNCT'),
#   ('Manchester', 'PROPN'),
#   ('United', 'XFAMIL'),
#   ('conserve', 'VERB'),
#   ('son', 'DET'),
#   ('trophée', 'NMS'),
#   ('en', 'PREP'),
#   ('battant', 'VERB'),
#   ('Aston', 'PROPN'),
#   ('Villa', 'XFAMIL'),
#   ('sur', 'PREP'),
#   ('le', 'DETMS'),
#   ('score', 'NMS'),
#   ('de', 'PREP'),
#   ('2', 'CHIF'),
#   ('buts', 'NMP'),
#   ('à', 'PREP'),
#   ('1', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Lors', 'ADV'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('tour', 'NMS'),
#   ('final', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('club', 'NMS'),
#   ('termina', 'VERB'),
#   ('2', 'CHIF'),
#   ('derrière', 'PREP'),
#   ('le', 'DETMS'),
#   ('VfB', 'PROPN'),
#   ('Speldorf', 'XFAMIL'),
#   ('et', 'COCO'),
#   ('monta', 'VERB'),
#   ('en', 'PREP'),
#   ('2', 'CHIF'),
#   ('.', 'YPFOR')],
#  [('Khaled', 'PROPN'),
#   ('Hadadah', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('secrétaire', 'NMS'),
#   ('général', 'ADJMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Parti', 'NMS'),
#   ('communiste', 'ADJMS'),
#   ('libanais', 'ADJ'),
#   (',', 'PUNCT'),
#   ("s'", 'PREF'),
#   ('est', 'AUX'),
#   ('dit', 'VPPMS'),
#   ('favorable', 'ADJ'),
#   ('à', 'PREP'),
#   ('un', 'DINTMS'),
#   ('soulèvement', 'NMS'),
#   ('arabe', 'ADJMS'),
#   ('de', 'PREP'),
#   ('solidarité', 'NFS'),
#   ('avec', 'PREP'),
#   ('ce', 'PDEMMS'),
#   ('réveil', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Monde', 'NMS'),
#   ('arabe', 'ADJMS'),
# ...
#   ('cloche', 'NFS'),
#   ('datée', 'VPPFS'),
#   ('de', 'PREP'),
#   ('1660', 'CHIF'),
#   ('qui', 'PREL'),
#   ('provient', 'VERB'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('collège', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('oratoriens', 'NMP'),
#   ('de', 'PREP'),
#   ('Thuin', 'PROPN'),
#   ('en', 'PREP'),
#   ('Belgique', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ('cultive', 'VERB'),
#   ("d'", 'PREP'),
#   ('ailleurs', 'ADV'),
#   ('cette', 'PDEMFS'),
#   ('ambiguïté', 'NFS'),
#   ('sur', 'PREP'),
#   ('elle', 'PPER3FS'),
#   ("puisqu'", 'COSUB'),
#   ('elle', 'PPER3FS'),
#   ('possède', 'VERB'),
#   ('deux', 'CHIF'),
#   ('tatouages', 'NMP'),
#   (':', 'PUNCT'),
#   ('un', 'PINDMS'),
#   ('représentant', 'VERB'),
#   ('le', 'DETMS'),
#   ('Aum', 'PROPN'),
#   ('et', 'COCO'),
#   ('un', 'DINTMS'),
#   ('autre', 'ADJMS'),
#   ('représentant', 'VERB'),
#   ('le', 'DETMS'),
#   ('démon', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Sa', 'DET'),
#   ('femme', 'NFS'),
#   ('le', 'PPOBJMS'),
#   ('trompa', 'VERB'),
#   ('régulièrement', 'ADV'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('étymologie', 'NFS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('onm', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('commune', 'NFS'),
#   ('fait', 'VERB'),
#   ('référence', 'NFS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('mot', 'NMS'),
#   ('slave', 'ADJMS'),
#   ('vlk', 'NOUN'),
#   ('sigifiant', 'VERB'),
#   ('loup', 'NMS'),
#   ('.', 'YPFOR')],
#  [('Jos', 'PROPN'),
#   ('Van', 'XFAMIL'),
#   ('Assche', 'XFAMIL'),
#   (',', 'PUNCT'),
#   ('né', 'VPPMS'),
#   ('le', 'DETMS'),
#   ('12', 'CHIF'),
#   ('février', 'NMS'),
#   ('1950', 'CHIF'),
#   ('à', 'PREP'),
#   ('Louvain', 'PROPN'),
#   ('est', 'AUX'),
#   ('un', 'DINTMS'),
#   ('homme', 'NMS'),
#   ('politique', 'ADJMS'),
#   ('belge', 'ADJMS'),
#   ('bruxellois', 'ADJ'),
#   (',', 'PUNCT'),
#   ('ex-membre', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Vlaams', 'PROPN'),
#   ('Belang', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [('Refusant', 'VERB'),
#   ('tout', 'DET'),
#   ('contact', 'NMS'),
#   ('avec', 'PREP'),
#   ('le', 'DETMS'),
#   ('monde', 'NMS'),
#   ('extérieur', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('ils', 'PPER3MP'),
#   ('constituent', 'VERB'),
#   ("l'", 'DET'),
#   ('un', 'PINDMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('derniers', 'ADJMP'),
#   ('peuples', 'NMP'),
#   ('coupés', 'VPPMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('monde', 'NMS'),
#   (',', 'PUNCT'),
#   ('vivant', 'VERB'),
#   ('en', 'PREP'),
#   ('autarcie', 'NFS'),
#   ('dans', 'PREP'),
#   ('des', 'DET'),
#   ('conditions', 'NFP'),
#   ("n'", 'ADV'),
#   ('ayant', 'AUX'),
#   ('pas', 'ADV'),
#   ('changé', 'VPPMS'),
#   ('depuis', 'PREP'),
#   ('des', 'DET'),
#   ('milliers', 'NMP'),
#   ("d'", 'PREP'),
#   ('années', 'NFP'),
#   ('.', 'YPFOR')],
#  [('Tant', 'ADV'),
#   ('que', 'COSUB'),
#   ('nous', 'PREFP'),
#   ("n'", 'ADV'),
#   ('aurons', 'AUX'),
#   ('pas', 'ADV'),
#   ('pu', 'VPPMS'),
#   ('reconnaître', 'VERB'),
#   ('cette', 'PDEMFS'),
#   ('faute', 'NFS'),
#   ('-là', 'ADV'),
#   (',', 'PUNCT'),
#   ('toute', 'DET'),
#   ('tentative', 'NFS'),
#   ('vers', 'PREP'),
#   ('un', 'DINTMS'),
#   ('quelconque', 'ADJMS'),
#   ('accord', 'NMS'),
#   ('sera', 'AUX'),
#   ('illusoire', 'ADJFS'),
#   ('et', 'COCO'),
#   ("d'", 'PREP'),
#   ('office', 'NMS'),
#   ('promise', 'VPPFS'),
#   ('à', 'PREP'),
#   ('un', 'DINTMS'),
#   ('nouvel', 'ADJMS'),
#   ('échec', 'NMS'),
#   ('.', 'YPFOR')],
#  [('La', 'DETFS'),
#   ('Coupe', 'NFS'),
#   ('Intertoto', 'PROPN'),
#   ('1995', 'CHIF'),
#   ('est', 'AUX'),
#   ('la', 'DETFS'),
#   ('première', 'ADJFS'),
#   ('édition', 'NFS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Coupe', 'NFS'),
#   ('Intertoto', 'PROPN'),
#   ('organisée', 'VPPFS'),
#   ('par', 'PREP'),
#   ("l'", 'DET'),
#   ('Union', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('associations', 'NFP'),
#   ('européennes', 'ADJFP'),
#   ('de', 'PREP'),
#   ('football', 'NMS'),
#   ('(', 'PUNCT'),
#   ('UEFA', 'PROPN'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Elle', 'PPER3FS'),
#   ("s'", 'PREF'),
#   ('attarde', 'VERB'),
#   ('sur', 'PREP'),
#   ('le', 'DETMS'),
#   ('pendant', 'NMS'),
#   ('social', 'ADJMS'),
#   (':', 'PUNCT'),
#   ('adaptation', 'NFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('formations', 'NFP'),
#   ('professionnelles', 'ADJFP'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('enjeux', 'NMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('durable', 'NMS'),
#   (',', 'PUNCT'),
#   ('emplois', 'NMP'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('personnes', 'NFP'),
#   ('en', 'PREP'),
#   ('situation', 'NFS'),
#   ('de', 'PREP'),
#   ('handicaps', 'NMP'),
#   (',', 'PUNCT'),
#   ('lutte', 'NFS'),
#   ('contre', 'PREP'),
#   ('le', 'DETMS'),
#   ('décrochage', 'NMS'),
#   ('scolaire', 'ADJMS'),
#   ('précoce', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('développement', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('financement', 'NMS'),
#   ('privé', 'ADJMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('recherche', 'NFS'),
#   ('dont', 'PREL'),
#   ('le', 'DETMS'),
#   ('budget', 'NMS'),
#   ('devrait', 'VERB'),
#   ('être', 'AUX'),
#   ('revu', 'VPPMS'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('hausse', 'NFS'),
#   ('(', 'PUNCT'),
#   ('3', 'CHIF'),
#   ('%', 'SYM'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('PIB', 'NMS'),
#   ('dès', 'PREP'),
#   ('2010', 'CHIF'),
#   (')', 'PUNCT'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('lance', 'VERB'),
#   ('également', 'ADV'),
#   ('une', 'DINTFS'),
#   ('collection', 'NFS'),
#   ('pour', 'PREP'),
#   ('homme', 'NMS'),
#   (':', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('retravaille', 'VERB'),
#   ('le', 'DETMS'),
#   ('classique', 'NMS'),
#   ('masculin', 'ADJMS'),
#   ('et', 'COCO'),
#   ('lui', 'PPOBJMS'),
#   ('donne', 'VERB'),
#   ('un', 'DINTMS'),
#   ('style', 'NMS'),
#   ('résolument', 'ADV'),
#   ('moderne', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('Espace', 'NMS'),
#   ('éthique', 'ADJMS'),
#   ('/', 'SYM'),
#   ('AP-HP', 'PROPN'),
#   ('propose', 'VERB'),
#   ('des', 'DET'),
#   ('formations', 'NFP'),
#   ('en', 'PREP'),
#   ('vue', 'NFS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('obtention', 'NFS'),
#   ("d'", 'PREP'),
#   ('un', 'DINTMS'),
#   ('diplôme', 'NMS'),
#   ('accessible', 'ADJMS'),
#   ('à', 'PREP'),
#   ("l'", 'DET'),
#   ('ensemble', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('professionnels', 'NMP'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('santé', 'NFS'),
#   (',', 'PUNCT'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('membres', 'NMP'),
#   ("d'", 'PREP'),
#   ('associations', 'NFP'),
#   ('à', 'PREP'),
#   ('caractère', 'NMS'),
#   ('médico-social', 'ADJMS'),
#   ('et', 'COCO'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('étudiants', 'NMP'),
#   ('en', 'PREP'),
#   ('formation', 'NFS'),
#   (':', 'PUNCT')],
#  [('À', 'PREP'),
#   ("l'", 'DET'),
#   ('hôpital', 'NMS'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ('a', 'AUX'),
#   ('avoué', 'VPPMS'),
#   ('le', 'DETMS'),
#   ('meurtre', 'NMS'),
#   ('et', 'COCO'),
#   ('a', 'AUX'),
#   ('demandé', 'VPPMS'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('personnel', 'NMS'),
#   ('infirmier', 'ADJMS'),
#   ("qu'", 'COSUB'),
#   ('il', 'PPER3MS'),
#   ('soit', 'AUX'),
#   ('transféré', 'VPPMS'),
#   ('dans', 'PREP'),
#   ('un', 'DINTMS'),
#   ('pénitencier', 'NMS'),
#   ('.', 'YPFOR')],
#  [('En', 'PREP'),
#   ('1995', 'CHIF'),
#   (',', 'PUNCT'),
#   ('David', 'PROPN'),
#   ('Miscavige', 'XFAMIL'),
#   ('a', 'AUX'),
#   ('initié', 'VPPMS'),
#   ('le', 'DETMS'),
#   ('développement', 'NMS'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('programme', 'NMS'),
#   ('«', 'PUNCT'),
#   ("l'", 'DET'),
#   ('Age', 'NMS'),
#   ("d'", 'PREP'),
#   ('Or', 'NMS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Tech', 'NFS'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('un', 'DINTMS'),
#   ('nouveau', 'ADJMS'),
#   ('concept', 'NMS'),
#   ("d'", 'PREP'),
#   ('entraînement', 'NMS'),
#   ('pour', 'PREP'),
#   ('les', 'DET'),
#   ('auditeurs', 'NMP'),
#   ('scientologues', 'ADJMP'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('est', 'AUX'),
#   ('exilé', 'VPPMS'),
#   ('et', 'COCO'),
#   ('meurt', 'VERB'),
#   ('dans', 'PREP'),
#   ("l'", 'DET'),
#   ('obscurité', 'NFS'),
#   ('.', 'YPFOR')],
#  [('Les', 'DET'),
#   ('mineurs', 'NMP'),
#   (',', 'PUNCT'),
#   ('pris', 'VERB'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('piège', 'NMS'),
#   ('à', 'PREP'),
#   ('688', 'CHIF'),
#   ('mètres', 'NMP'),
#   ('de', 'PREP'),
#   ('profondeur', 'NFS'),
#   ('et', 'COCO'),
#   ('à', 'PREP'),
#   ('environ', 'ADV'),
#   ('5', 'CHIF'),
#   ('km', 'NMP'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('entrée', 'NFS'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('mine', 'NFS'),
#   (',', 'PUNCT'),
#   ('se', 'PREF'),
#   ('sont', 'AUX'),
#   ('installés', 'VPPMP'),
#   ('dans', 'PREP'),
#   ('un', 'DINTMS'),
#   ('refuge', 'NMS'),
#   ('de', 'PREP'),
#   ('sécurité', 'NFS'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('agitateur', 'NMS'),
#   ('de', 'PREP'),
#   ('Parr', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('Parr', 'PROPN'),
#   ('shaker', 'NMS'),
#   (')', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('le', 'DETMS'),
#   ('premier', 'ADJMS'),
#   ('appareil', 'NMS'),
#   ('permettant', 'VERB'),
#   ("l'", 'DET'),
#   ('hydrogénation', 'NFS'),
#   ('à', 'PREP'),
#   ('hautes', 'ADJFP'),
#   ('température', 'NFS'),
#   ('et', 'COCO'),
#   ('pression', 'NFS'),
#   (',', 'PUNCT'),
#   ('basé', 'VPPMS'),
#   ('sur', 'PREP'),
#   ('les', 'DET'),
#   ('travaux', 'NMP'),
#   ('de', 'PREP'),
#   ('Voorhees', 'PROPN'),
#   ('et', 'COCO'),
#   ('Adams', 'PROPN'),
#   (',', 'PUNCT'),
#   ('a', 'AUX'),
#   ('été', 'AUX'),
#   ('commercialisé', 'VPPMS'),
#   ('en', 'PREP'),
#   ('1926', 'CHIF'),
#   ('et', 'COCO'),
#   ('reste', 'VERB'),
#   ("d'", 'PREP'),
#   ('usage', 'NMS'),
#   ('courant', 'ADJMS'),
#   ('.', 'YPFOR')],
#  [('"', 'PUNCT'),
#   ('Les', 'DET'),
#   ('dimanches', 'NMP'),
#   ('et', 'COCO'),
#   ('jours', 'NMP'),
#   ('fériés', 'ADJMP'),
#   (',', 'PUNCT'),
#   ('il', 'PPER3MS'),
#   ("n'", 'ADV'),
#   ('y', 'PPOBJMS'),
#   ('a', 'VERB'),
#   ('pas', 'ADV'),
#   ('de', 'DET'),
#   ('cars', 'NMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('tout', 'PINDMS'),
#   (',', 'PUNCT'),
#   ('"', 'PUNCT'),
#   ("s'", 'PREF'),
#   ('est', 'AUX'),
#   ('plaint', 'VPPMS'),
#   ('une', 'DINTFS'),
#   ('habitante', 'NFS'),
#   ('.', 'YPFOR')],
#  [('NVE', 'PROPN'),
#   ('demande', 'VERB'),
#   ('ainsi', 'ADV'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('propriétaires', 'NMP'),
#   ('de', 'PREP'),
#   ('puits', 'NOUN'),
#   ('et', 'COCO'),
#   ('aux', '_'),
#   ('à', 'PREP'),
#   ('les', 'DET'),
#   ('autorités', 'NFP'),
#   ('compétentes', 'ADJFP'),
#   ('de', 'PREP'),
#   ('surveiller', 'VERB'),
#   ('les', 'DET'),
#   ('niveaux', 'NMP'),
#   ("d'", 'PREP'),
#   ('eau', 'NFS'),
#   ('de', 'PREP'),
#   ('leurs', 'DET'),
#   ('ouvrages', 'NMP'),
#   ('.', 'YPFOR')],
#  [('En', 'PREP'),
#   ('966', 'CHIF'),
#   (',', 'PUNCT'),
#   ('elle', 'PPER3FS'),
#   ('donne', 'VERB'),
#   ('naissance', 'NFS'),
#   ('à', 'PREP'),
#   ('un', 'DINTMS'),
#   ('fils', 'NMS'),
#   (',', 'PUNCT'),
#   ('nommé', 'VPPMS'),
#   ('Edmond', 'PROPN'),
#   ('.', 'YPFOR')],
#  [('Si', 'COSUB'),
#   ('vous', 'PREFP'),
#   ('voulez', 'VERB'),
#   ('un', 'DINTMS'),
#   ('établissement', 'NMS'),
#   ('où', 'ADV'),
#   ('la', 'DETFS'),
#   ('serveuse', 'NFS'),
#   ('change', 'VERB'),
#   ('son', 'DET'),
#   ('petit', 'NMS'),
#   ('à', 'PREP'),
#   ('même', 'ADV'),
#   ('une', 'DINTFS'),
#   ('banquette', 'NFS'),
#   (',', 'PUNCT'),
#   ('où', 'ADV'),
#   ('la', 'DETFS'),
#   ('boisson', 'NFS'),
#   ("n'", 'ADV'),
#   ('est', 'AUX'),
#   ('pas', 'ADV'),
#   ('servie', 'VPPFS'),
#   ('dans', 'PREP'),
#   ('sa', 'DET'),
#   ('bouteille', 'NFS'),
#   ("d'", 'PREP'),
#   ('origine', 'NFS'),
#   ('(', 'PUNCT'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('piètre', 'ADJFS'),
#   ('fraîcheur', 'NFS'),
#   (')', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('et', 'COCO'),
#   ('les', 'DET'),
#   ('pizzas', 'NFP'),
#   ('à', 'PREP'),
#   ('la', 'DETFS'),
#   ('limite', 'NFS'),
#   ('de', 'PREP'),
#   ("l'", 'DET'),
#   ('indigeste', 'ADJMS'),
#   (',', 'PUNCT'),
#   ('vous', 'PREFP'),
#   ('allez', 'VERB'),
#   ('être', 'AUX'),
#   ('servi', 'VPPMS'),
#   ('!', 'PUNCT')],
#  [('Léopold', 'PROPN'),
#   ('Georges', 'XFAMIL'),
#   ('Pelletier', 'XFAMIL'),
#   ('est', 'AUX'),
#   ('un', 'PINDMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('premiers', 'ADJMP'),
#   ('pasteurs', 'NMP'),
#   ('piétistes', 'ADJMP'),
#   ('du', '_'),
#   ('de', 'PREP'),
#   ('le', 'DETMS'),
#   ('Ban', 'PROPN'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('Roche', 'PROPN'),
#   (',', 'PUNCT'),
#   ('prédécesseur', 'NMS'),
#   ('(', 'PUNCT'),
#   ('de', 'PREP'),
#   ('1707', 'CHIF'),
#   ('à', 'PREP'),
#   ('1712', 'CHIF'),
#   (')', 'PUNCT'),
#   ('de', 'PREP'),
#   ('Jean', 'PROPN'),
#   ('Georges', 'XFAMIL'),
#   ('Stuber', 'XFAMIL'),
#   ('et', 'COCO'),
#   ('de', 'PREP'),
#   ('Jean-Frédéric', 'PROPN'),
#   ('Oberlin', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('un', 'PINDMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('grands', 'ADJMP'),
#   ('chocs', 'NMP'),
#   ('de', 'PREP'),
#   ('la', 'DETFS'),
#   ('saison', 'NFS'),
#   ('fut', 'AUX'),
#   ('le', 'DETMS'),
#   ('match', 'NMS'),
#   ('Amnéville-Thionville', 'PROPN'),
#   ('qui', 'PREL'),
#   ('se', 'PREF'),
#   ('joua', 'VERB'),
#   ('devant', 'PREP'),
#   ('plus', 'ADV'),
#   ('de', 'PREP'),
#   ('4000', 'CHIF'),
#   ('spectateurs', 'NMP'),
#   ('.', 'YPFOR')],
#  [('Merci', 'INTJ'),
#   ('pour', 'PREP'),
#   ("l'", 'DET'),
#   ('aide', 'NFS'),
#   ('que', 'PREL'),
#   ('vous', 'PREFP'),
#   ('apportez', 'VERB'),
#   ('.', 'YPFOR')],
#  [('Ce', 'PDEMMS'),
#   ("n'", 'ADV'),
#   ('est', 'AUX'),
#   ('pas', 'ADV'),
#   ('un', 'DINTMS'),
#   ('résultat', 'NMS'),
#   ('satisfaisant', 'ADJMS'),
#   ('car', 'COCO'),
#   ('il', 'PPER3MS'),
#   ('est', 'AUX'),
#   ('expérimentalement', 'ADV'),
#   ('établi', 'VPPMS'),
#   ('que', 'COSUB'),
#   ('plus', 'ADV'),
#   ('on', 'PINDMS'),
#   ('comprime', 'VERB'),
#   ('un', 'DINTMS'),
#   ('solide', 'NMS'),
#   (',', 'PUNCT'),
#   ('plus', 'ADV'),
#   ('il', 'PPER3MS'),
#   ('devient', 'VERB'),
#   ('difficile', 'ADJMS'),
#   ('de', 'PREP'),
#   ('le', 'PPOBJMS'),
#   ('comprimer', 'VERB'),
#   ('.', 'YPFOR')],
#  [('Ils', 'PPER3MP'),
#   ('seront', 'AUX'),
#   ('donc', 'ADV'),
#   ('persécutés', 'VPPMP'),
#   ('et', 'COCO'),
#   ('rejetés', 'VPPMP'),
#   ('par', 'PREP'),
#   ("l'", 'DET'),
#   ('Antéchrist', 'PROPN'),
#   ('et', 'COCO'),
#   ('son', 'DET'),
#   ('gouvernement', 'NMS'),
#   ('...', 'PUNCT')],
#  [('Nous', 'PREFP'),
#   ('sommes', 'AUX'),
#   ('unanimes', 'ADJ'),
#   (':', 'PUNCT'),
#   ("c'", 'PDEMMS'),
#   ('est', 'AUX'),
#   ('une', 'PINDFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('meilleures', 'ADJFP'),
#   ('expériences', 'NFP'),
#   ('de', 'PREP'),
#   ('gastronomie', 'NFS'),
#   ('japonaise', 'ADJFS'),
#   ('jamais', 'ADV'),
#   ('faite', 'VPPFS'),
#   ('.', 'YPFOR')],
#  [("L'", 'DET'),
#   ('année', 'NFS'),
#   ('suivante', 'ADJFS'),
#   ('(', 'PUNCT'),
#   ('1926', 'CHIF'),
#   (')', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('elle', 'PPER3FS'),
#   ('est', 'AUX'),
#   ('au', '_'),
#   ('à', 'PREP'),
#   ('le', 'DETMS'),
#   ('nombre', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('treize', 'CHIF'),
#   ('jeunes', 'ADJFP'),
#   ('actrices', 'NFP'),
#   ('(', 'PUNCT'),
#   ('dont', 'PREL'),
#   ('Mary', 'PROPN'),
#   ('Astor', 'XFAMIL'),
#   ('et', 'COCO'),
#   ('Joan', 'PROPN'),
#   ('Crawford', 'XFAMIL'),
#   (')', 'PUNCT'),
#   ('recevant', 'VERB'),
#   ('le', 'DETMS'),
#   ('WAMPAS', 'PROPN'),
#   ('Baby', 'NMS'),
#   ('Stars', 'NFP'),
#   ('.', 'YPFOR')],
#  [('Il', 'PPER3MS'),
#   ('développa', 'VERB'),
#   ('une', 'DINTFS'),
#   ('critique', 'NFS'),
#   ('sérieuse', 'ADJFS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('institutions', 'NFP'),
#   ('libérales', 'ADJFP'),
#   ('depuis', 'PREP'),
#   ('le', 'DETMS'),
#   ('milieu', 'NMS'),
#   ('des', '_'),
#   ('de', 'PREP'),
#   ('les', 'DET'),
#   ('années', 'NFP'),
#   ('1990', 'CHIF'),
#   (',', 'PUNCT'),
#   ('durant', 'PREP'),
#   ('lesquelles', 'PRELFP'),
#   ('il', 'PPER3MS'),
#   ('publie', 'VERB'),
#   ('ses', 'DET'),
#   ('premiers', 'ADJMP'),
#   ('articles', 'NMP'),
#   ('académiques', 'ADJMP'),
#   (',', 'PUNCT'),
#   ('en', 'PREP'),
#   ('particulier', 'ADJMS'),
#   ('contre', 'PREP'),
#   ('la', 'DETFS'),
#   ('théorie', 'NFS'),
#   ('politique', 'ADJFS'),
#   ('de', 'PREP'),
#   ('John', 'PROPN'),
#   ('Rawls', 'XFAMIL'),
#   ('.', 'YPFOR')],
#  [('Cette', 'PDEMFS'),
#   ('série', 'NFS'),
#   ('de', 'PREP'),
#   ('publications', 'NFP'),
#   ('a', 'AUX'),
#   ('débuté', 'VPPMS'),
#   ('en', 'PREP'),
#   ('1927', 'CHIF'),
#   ('.', 'YPFOR')],
#  ...]

# %%
dev_data = read_data('C:/Users/rim-1/Downloads/dev.conllu')
test_data = read_data('C:/Users/rim-1/Downloads/test.conllu')

# %%
#step 2 : 
def train_hmm(train_data, k=0.1):
    transition_probs = defaultdict(lambda: defaultdict(lambda: k))
    emission_probs = defaultdict(lambda: defaultdict(lambda: k))
    tag_counts = defaultdict(int)

    for sentence in train_data:
        previous_tag = None
        for word, tag in sentence:
            if previous_tag is not None:
                transition_probs[previous_tag][tag] += 1
            emission_probs[tag][word] += 1
            tag_counts[tag] += 1
            previous_tag = tag

    total_tags = sum(tag_counts.values())

    for tag, transitions in transition_probs.items():
        total_transitions = sum(transitions.values())
        for next_tag in transitions:
            transition_probs[tag][next_tag] = (transition_probs[tag][next_tag] + k) / (total_transitions + k * total_tags)

    for tag, emissions in emission_probs.items():
        total_emissions = sum(emissions.values())
        for word in emissions:
            emission_probs[tag][word] = (emission_probs[tag][word] + k) / (total_emissions + k * total_tags)

    for tag in tag_counts:
        tag_counts[tag] /= total_tags

    return transition_probs, emission_probs, tag_counts

# %%
transition_probs, emission_probs, tag_counts = train_hmm(train_data, k=0.1)

# Print tag counts
print("Tag counts:")
for tag, count in tag_counts.items():
    print(f"{tag}: {count}")
# Out:
# Tag counts:
# DET: 0.06129013665469097
# NFP: 0.01795805669838534
# ADJFP: 0.007330883301449984
# AUX: 0.03130789435403967
# VPPMS: 0.01526009403072329
# ADV: 0.036113726125226085
# PREP: 0.1550820778978397
# PDEMMS: 0.004696046922044523
# NMS: 0.0720902211890248
# COSUB: 0.007199141482479711
# PINDMS: 0.0023411619079508933
# PPOBJMS: 0.0034280319144556455
# VERB: 0.051338140079978264
# DETFS: 0.026707909174994306
# NFS: 0.06202020590148456
# YPFOR: 0.03666813961339265
# VPPFS: 0.005996997384375969
# _: 0.02658714584093822
# PUNCT: 0.07041600223961092
# DETMS: 0.037480547497042674
# PROPN: 0.054145887596782204
# ADJMS: 0.020085138150509538
# PPER3FS: 0.0024152666811216718
# ADJFS: 0.01944289678302946
# COCO: 0.024627486283755412
# NMP: 0.026334640687911866
# PREL: 0.007256778528279204
# PPER1S: 0.0013393751595311089
# ADJMP: 0.007959401562787327
# VPPMP: 0.0033731394898846986
# DINTMS: 0.010278606500909842
# PPER3MS: 0.009603429678687193
# PPER3MP: 0.0012735042500459724
# PREF: 0.005634707382207719
# ADJ: 0.0026128794095770813
# DINTFS: 0.008716917021866397
# CHIF: 0.025365789394234648
# XFAMIL: 0.01567727645746249
# PRELFS: 0.0001811450010841254
# SYM: 0.0016632404644996968
# NOUN: 0.003417053429541456
# MOTINC: 0.0051022508638695315
# PINDFS: 0.00033758841111132456
# PPOBJMP: 0.0005214780334239973
# NUM: 0.00015918803125574655
# PREFP: 0.001594624933786013
# PDEMFS: 0.0024427128934071452
# VPPFP: 0.0019788719057826426
# PPER3FP: 0.00030190833514020897
# PPOBJFS: 0.000875534171906606
# PINDMP: 0.0002223143195123357
# PRON: 0.0015809018276432762
# PPOBJFP: 0.00017565575862703067
# PART: 0.00021956969828378835
# PDEMMP: 0.00025524977425490393
# PRELMS: 0.0002223143195123357
# PDEMFP: 0.00012899719774172566
# X: 0.0004528625027103135
# PRELFP: 5.489242457094709e-05
# INTJ: 0.00017565575862703067
# PREFS: 0.0002826959865403775
# PINDFP: 7.684939439932592e-05
# PRELMP: 7.136015194223121e-05
# PINTFS: 5.4892424570947085e-06
# PPER2S: 4.116931842821031e-05
# VPPRE: 2.7446212285473543e-06

# %%
# transition probability from 'DET' to 'NFP'
print("Transition probability from 'DET' to 'NFP':", transition_probs['DET']['NFP'])

# transition probability from 'NFP' to 'ADJFP'
print("Transition probability from 'NFP' to 'ADJFP':", transition_probs['NFP']['ADJFP'])
# Out:
# Transition probability from 'DET' to 'NFP': 0.07082232991206344
# Transition probability from 'NFP' to 'ADJFP': 0.03379323344138541

# %%
#step 3:
def viterbi(obs, states, transition_probs, emission_probs, tag_counts):
    V = [{}]
    for st in states:
        V[0][st] = {"prob": tag_counts[st] * emission_probs[st].get(obs[0], 1e-10), "prev": None}
    for t in range(1, len(obs)):
        V.append({})
        for st in states:
            max_tr_prob = max(V[t-1][prev_st]["prob"] * transition_probs[prev_st].get(st, 1e-10) for prev_st in states)
            for prev_st in states:
                if V[t-1][prev_st]["prob"] * transition_probs[prev_st].get(st, 1e-10) == max_tr_prob:
                    max_prob = max_tr_prob * emission_probs[st].get(obs[t], 1e-10)
                    V[t][st] = {"prob": max_prob, "prev": prev_st}
                    break
    opt = []
    max_prob = max(value["prob"] for value in V[-1].values())
    previous = None
    for st, data in V[-1].items():
        if data["prob"] == max_prob:
            opt.append(st)
            previous = st
            break
    for t in range(len(V) - 2, -1, -1):
        opt.insert(0, V[t + 1][previous]["prev"])
        previous = V[t + 1][previous]["prev"]
    return opt

# %%
# Defining states and trying the viterbi algo on a sample :

states = transition_probs.keys()

sample_sentence = ["Le", "chat", "noir", "mange", "."]
tag_sequence = viterbi(sample_sentence, states, transition_probs, emission_probs, tag_counts)

print("Sample sentence:", sample_sentence)
print("Predicted POS tags:", tag_sequence)
# Out:
# Sample sentence: ['Le', 'chat', 'noir', 'mange', '.']
# Predicted POS tags: ['DETMS', 'NMS', 'ADJMS', 'VERB', 'YPFOR']

# %%
#step 4 :
def predict_pos_tags(dev_data, transition_probs, emission_probs, tag_counts):
    predicted_tags = []
    for sentence in dev_data:
        words = [word for word, _ in sentence]
        predicted_tags.extend(viterbi(words, states, transition_probs, emission_probs, tag_counts))
    return predicted_tags

#trying it in the dev set:
# Training the HMM model
transition_probs, emission_probs, tag_counts = train_hmm(train_data, k=0.1)
states = transition_probs.keys()
predicted_tags_dev = predict_pos_tags(dev_data, transition_probs, emission_probs, tag_counts)
true_tags_dev = [tag for sentence in dev_data for _, tag in sentence]

# %%
#evaluation
from sklearn.metrics import accuracy_score, classification_report

def evaluate_performance(true_tags, predicted_tags):
    accuracy = accuracy_score(true_tags, predicted_tags)
    report = classification_report(true_tags, predicted_tags)
    return accuracy, report

# %%
# Évaluer les performances
accuracy_dev, report_dev = evaluate_performance(true_tags_dev, predicted_tags_dev)
print("Accuracy on dev set:", accuracy_dev)
print("Classification report on dev set:\n", report_dev)
# Out:
# C:\Users\rim-1\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy on dev set: 0.906512576478586
# Classification report on dev set:
#                precision    recall  f1-score   support
#
#          ADJ       0.96      0.54      0.70       101
#        ADJFP       0.88      0.72      0.79       294
#        ADJFS       0.86      0.81      0.84       738
#        ADJMP       0.82      0.67      0.74       292
#        ADJMS       0.85      0.80      0.82       776
#          ADV       0.89      0.96      0.92      1307
#          AUX       0.94      0.94      0.94      1124
#         CHIF       0.97      0.86      0.91       953
#         COCO       0.99      0.99      0.99       884
#        COSUB       0.86      0.74      0.79       256
#          DET       0.93      0.98      0.95      2230
#        DETFS       0.99      1.00      0.99      1007
#        DETMS       0.95      1.00      0.97      1426
#       DINTFS       0.98      1.00      0.99       306
#       DINTMS       0.99      0.99      0.99       387
#         INTJ       1.00      0.40      0.57         5
#       MOTINC       0.58      0.30      0.39       148
#          NFP       0.97      0.87      0.92       706
#          NFS       0.85      0.95      0.90      2257
#          NMP       0.91      0.82      0.86       982
#          NMS       0.85      0.93      0.89      2679
#         NOUN       0.72      0.17      0.28       105
#          NUM       0.00      0.00      0.00         6
#         PART       1.00      0.56      0.71         9
#       PDEMFP       1.00      1.00      1.00         3
#       PDEMFS       1.00      1.00      1.00        85
#       PDEMMP       1.00      1.00      1.00        12
#       PDEMMS       0.87      1.00      0.93       164
#       PINDFP       0.00      0.00      0.00         2
#       PINDFS       1.00      0.25      0.40        12
#       PINDMP       0.00      0.00      0.00         7
#       PINDMS       1.00      0.75      0.86        64
#       PINTFS       0.00      0.00      0.00         1
#       PPER1S       1.00      0.93      0.96        41
#       PPER2S       0.50      0.50      0.50         2
#      PPER3FP       1.00      0.89      0.94         9
#      PPER3FS       1.00      0.97      0.98        94
#      PPER3MP       1.00      1.00      1.00        29
#      PPER3MS       1.00      0.98      0.99       352
#      PPOBJFP       0.00      0.00      0.00         4
#      PPOBJFS       1.00      0.15      0.26        33
#      PPOBJMP       1.00      0.08      0.15        12
#      PPOBJMS       0.85      0.73      0.78       129
#         PREF       1.00      0.98      0.99       232
#        PREFP       1.00      0.98      0.99        61
#        PREFS       1.00      0.86      0.92         7
#         PREL       0.98      0.90      0.94       262
#       PRELFP       1.00      1.00      1.00         5
#       PRELFS       1.00      1.00      1.00         4
#       PRELMP       1.00      1.00      1.00         3
#       PRELMS       1.00      0.73      0.84        11
#         PREP       0.93      1.00      0.96      5751
#         PRON       1.00      0.17      0.29        60
#        PROPN       0.75      0.65      0.70      2012
#        PUNCT       0.89      1.00      0.94      2429
#          SYM       0.98      0.79      0.87        61
#         VERB       0.91      0.88      0.90      1843
#        VPPFP       0.93      0.58      0.71        73
#        VPPFS       0.97      0.79      0.87       209
#        VPPMP       0.93      0.66      0.77        97
#        VPPMS       0.92      0.88      0.90       558
#        VPPRE       0.00      0.00      0.00         1
#            X       0.17      0.11      0.13         9
#       XFAMIL       0.75      0.37      0.50       622
#        YPFOR       1.00      1.00      1.00      1375
#            _       0.90      1.00      0.95      1057
#
#     accuracy                           0.91     36775
#    macro avg       0.83      0.71      0.74     36775
# weighted avg       0.90      0.91      0.90     36775
# C:\Users\rim-1\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\rim-1\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# trying on the test set
predicted_tags_test = predict_pos_tags(test_data, transition_probs, emission_probs, tag_counts)
true_tags_test = [tag for sentence in test_data for _, tag in sentence]

# %%
# Evaluating performance on test set
accuracy_test, report_test = evaluate_performance(true_tags_test, predicted_tags_test)
print("Accuracy on test set:", accuracy_test)
print("Classification report on test set:\n", report_test)
# Out:
# Accuracy on test set: 0.9105651582831618
# Classification report on test set:
#                precision    recall  f1-score   support
#
#          ADJ       1.00      0.64      0.78        22
#        ADJFP       0.85      0.62      0.72        76
#        ADJFS       0.88      0.79      0.83       182
#        ADJMP       0.79      0.68      0.73        82
#        ADJMS       0.87      0.79      0.83       244
#          ADV       0.90      0.97      0.93       504
#          AUX       0.90      0.91      0.91       355
#         CHIF       0.95      0.86      0.90       222
#         COCO       1.00      1.00      1.00       245
#        COSUB       0.89      0.74      0.81       128
#          DET       0.94      0.98      0.96       645
#        DETFS       1.00      1.00      1.00       240
#        DETMS       0.96      1.00      0.98       362
#       DINTFS       0.95      1.00      0.98        61
#       DINTMS       0.99      1.00      1.00       122
#         INTJ       0.67      0.33      0.44         6
#       MOTINC       0.20      0.13      0.16        15
#          NFP       0.95      0.88      0.91       199
#          NFS       0.88      0.95      0.91       560
#          NMP       0.90      0.79      0.84       305
#          NMS       0.84      0.93      0.88       753
#         NOUN       0.57      0.10      0.17        39
#          NUM       0.00      0.00      0.00         3
#         PART       1.00      1.00      1.00         4
#       PDEMFP       1.00      1.00      1.00         3
#       PDEMFS       1.00      1.00      1.00        29
#       PDEMMP       1.00      1.00      1.00         3
#       PDEMMS       0.87      0.97      0.92        75
#       PINDFP       0.00      0.00      0.00         1
#       PINDFS       0.00      0.00      0.00         1
#       PINDMP       0.00      0.00      0.00         1
#       PINDMS       1.00      0.89      0.94        44
#       PPER1S       1.00      1.00      1.00        42
#       PPER2S       1.00      1.00      1.00         2
#      PPER3FP       1.00      1.00      1.00         2
#      PPER3FS       1.00      1.00      1.00        18
#      PPER3MP       1.00      1.00      1.00        20
#      PPER3MS       0.96      0.94      0.95        87
#      PPOBJFP       0.00      0.00      0.00         2
#      PPOBJFS       0.50      0.17      0.25         6
#      PPOBJMP       1.00      0.20      0.33        10
#      PPOBJMS       0.82      0.79      0.80        47
#         PREF       1.00      0.98      0.99        52
#        PREFP       1.00      0.98      0.99        44
#        PREFS       1.00      0.90      0.95        10
#         PREL       0.94      0.87      0.90        70
#       PRELMS       0.00      0.00      0.00         2
#         PREP       0.94      1.00      0.97      1483
#         PRON       0.90      0.29      0.44        31
#        PROPN       0.71      0.71      0.71       395
#        PUNCT       0.93      1.00      0.96       833
#          SYM       1.00      0.82      0.90        38
#         VERB       0.90      0.85      0.87       583
#        VPPFP       0.89      0.42      0.57        19
#        VPPFS       0.82      0.82      0.82        40
#        VPPMP       0.95      0.77      0.85        26
#        VPPMS       0.89      0.84      0.87       157
#            X       0.00      0.00      0.00         1
#       XFAMIL       0.77      0.40      0.53       115
#        YPFOR       1.00      0.99      1.00       353
#            _       0.91      0.99      0.95       279
#
#     accuracy                           0.91     10298
#    macro avg       0.80      0.72      0.74     10298
# weighted avg       0.91      0.91      0.91     10298
# C:\Users\rim-1\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\rim-1\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\rim-1\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#trying to actually see if it works by using a phrase from the test set knowing its real pos tags and seeing whether my model predicts them right 
#for that i changed my predict funciton to return a list of predicted tags for each word:
def predict_pos_tagss(sentence, transition_probs, emission_probs, tag_counts):
    predicted_tags = []
    for word, _ in sentence:
        predicted_tag = viterbi([word], states, transition_probs, emission_probs, tag_counts)[0]
        predicted_tags.append(predicted_tag)
    return predicted_tags

# %%
# Parse the provided sentence into a list of (word, POS) tuples
test_sentence = [("Je", "PPER1S"), ("sens", "VERB"), ("qu'", "COSUB"), ("entre", "PREP"), ("ça", "PDEMMS"),
                 ("et", "COCO"), ("les", "DET"), ("films", "NMP"), ("de", "PREP"), ("médecins", "NMP"),
                 ("et", "COCO"), ("scientifiques", "NMP"), ("fous", "ADJMP"), ("que", "PREL"), ("nous", "PREFP"),
                 ("avons", "AUX"), ("déjà", "ADV"), ("vus", "VPPMP"), (",", "PUNCT"), ("nous", "PREFP"),
                 ("pourrions", "VERB"), ("emprunter", "VERB"), ("un", "DINTMS"), ("autre", "ADJMS"),
                 ("chemin", "NMS"), ("pour", "PREP"), ("l'", "DET"), ("origine", "NFS"), (".", "YPFOR")]

# Predict POS tags for the test sentence
predicted_tags_test = predict_pos_tags([test_sentence], transition_probs, emission_probs, tag_counts)[0]

# Display the predicted tags
print("Predicted tags for the test sentence:", predicted_tags_test)

# Evaluate the performance of your model (if gold-standard annotations are available in the test sentence)
accuracy_test, report_test = evaluate_performance([tag for _, tag in test_sentence], predicted_tags_test)
print("Accuracy on test sentence:", accuracy_test)
print("Classification report on test sentence:\n", report_test)

predicted_tags_test = predict_pos_tagss(test_sentence, transition_probs, emission_probs, tag_counts)
print("Predicted tags for the test sentence:", predicted_tags_test)
# Out:
# Predicted tags for the test sentence: ['PPER1S', 'NMS', 'COSUB', 'PREP', 'PDEMMS', 'COCO', 'DET', 'NMP', 'PREP', 'NMP', 'COCO', 'NMP', 'NMP', 'COSUB', 'PREFP', 'AUX', 'ADV', 'VPPMP', 'PUNCT', 'PREFP', 'PREP', 'PREP', 'DINTMS', 'ADJMS', 'NMS', 'PREP', 'DET', 'NFS', 'YPFOR']

# %%
# Evaluating
accuracy_test, report_test = evaluate_performance([tag for _, tag in test_sentence], predicted_tags_test)
print("Accuracy on test sentence:", accuracy_test)
print("Classification report on test sentence:\n", report_test)
# Out:
# Accuracy on test sentence: 0.8275862068965517
# Classification report on test sentence:
#                precision    recall  f1-score   support
#
#        ADJMP       0.00      0.00      0.00         1
#        ADJMS       1.00      1.00      1.00         1
#          ADV       1.00      1.00      1.00         1
#          AUX       1.00      1.00      1.00         1
#         COCO       1.00      1.00      1.00         2
#        COSUB       0.50      1.00      0.67         1
#          DET       1.00      1.00      1.00         2
#       DINTMS       1.00      1.00      1.00         1
#          NFS       1.00      1.00      1.00         1
#          NMP       0.75      1.00      0.86         3
#          NMS       0.50      1.00      0.67         1
#       PDEMMS       1.00      1.00      1.00         1
#       PPER1S       1.00      1.00      1.00         1
#        PREFP       1.00      1.00      1.00         2
#         PREL       0.00      0.00      0.00         1
#         PREP       0.60      1.00      0.75         3
#        PUNCT       1.00      1.00      1.00         1
#         VERB       0.00      0.00      0.00         3
#        VPPMP       1.00      1.00      1.00         1
#        YPFOR       1.00      1.00      1.00         1
#
#     accuracy                           0.83        29
#    macro avg       0.77      0.85      0.80        29
# weighted avg       0.73      0.83      0.76        29
# C:\Users\rim-1\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\rim-1\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\rim-1\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
